# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#zip function: zipping the pairs in a tuple, indexing! #the output is a zip object in memory.
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Unpack zip into a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
#Import the request library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nome
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | lubango
# Processing Record 4 of Set 1 | soyo
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | clyde river
# Processing Record 10 of Set 1 | henties bay
# Processing Record 11 of Set 1 | conde
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | miltenberg
# Processing Record 14 of Set 1 | yanchukan
# City not found. Skipping...
# Processing Record 15 of Set 1 | san patricio
# Processing Record 16 of Set 1 | marsa matruh
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | ahome
# Processing Record 20 of Set 1 | batticaloa
# Processing Record 21 of Set 1 | iskateley
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | souillac
# Processing Record 25 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | ancud
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | sorland
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | itarema
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | inyonga
# Processing Record 34 of Set 1 | celestun
# Processing Record 35 of Set 1 | axim
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | bosaso
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | lorengau
# Processing Record 43 of Set 1 | caravelas
# Processing Record 44 of Set 1 | kiknur
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | waipawa
# Processing Record 1 of Set 2 | egvekinot
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | mbandaka
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | mount vernon
# Processing Record 7 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 10 of Set 2 | sandakan
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | boali
# Processing Record 13 of Set 2 | malanje
# Processing Record 14 of Set 2 | guerrero negro
# Processing Record 15 of Set 2 | faanui
# Processing Record 16 of Set 2 | nyurba
# Processing Record 17 of Set 2 | puerto lempira
# Processing Record 18 of Set 2 | san jose
# Processing Record 19 of Set 2 | ramjibanpur
# Processing Record 20 of Set 2 | almeirim
# Processing Record 21 of Set 2 | kedarnath
# City not found. Skipping...
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | aksarka
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | mount isa
# Processing Record 26 of Set 2 | carballo
# Processing Record 27 of Set 2 | ruwi
# Processing Record 28 of Set 2 | corinto
# Processing Record 29 of Set 2 | sioux lookout
# Processing Record 30 of Set 2 | am timan
# Processing Record 31 of Set 2 | yumbe
# Processing Record 32 of Set 2 | torbay
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | muroto
# Processing Record 37 of Set 2 | quballat
# Processing Record 38 of Set 2 | soe
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | agirish
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | dunedin
# Processing Record 43 of Set 2 | vanavara
# Processing Record 44 of Set 2 | dukat
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | mapastepec
# Processing Record 48 of Set 2 | san juan
# Processing Record 49 of Set 2 | barao de melgaco
# Processing Record 50 of Set 2 | erie
# Processing Record 1 of Set 3 | bubaque
# Processing Record 2 of Set 3 | vallenar
# Processing Record 3 of Set 3 | the valley
# Processing Record 4 of Set 3 | anori
# Processing Record 5 of Set 3 | vokhma
# Processing Record 6 of Set 3 | kjollefjord
# Processing Record 7 of Set 3 | carutapera
# Processing Record 8 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | kinlochleven
# Processing Record 11 of Set 3 | san policarpo
# Processing Record 12 of Set 3 | san cristobal
# Processing Record 13 of Set 3 | iqaluit
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | constitucion
# Processing Record 17 of Set 3 | portland
# Processing Record 18 of Set 3 | yankton
# Processing Record 19 of Set 3 | cockburn town
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | ust-maya
# Processing Record 23 of Set 3 | nikolskoye
# Processing Record 24 of Set 3 | wa
# City not found. Skipping...
# Processing Record 25 of Set 3 | klaksvik
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | areia branca
# Processing Record 28 of Set 3 | coyuca
# City not found. Skipping...
# Processing Record 29 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 3 | hambantota
# Processing Record 31 of Set 3 | atuona
# Processing Record 32 of Set 3 | deming
# Processing Record 33 of Set 3 | manaus
# Processing Record 34 of Set 3 | kloulklubed
# Processing Record 35 of Set 3 | talnakh
# Processing Record 36 of Set 3 | kandrian
# Processing Record 37 of Set 3 | mount gambier
# Processing Record 38 of Set 3 | saint-philippe
# Processing Record 39 of Set 3 | gornopravdinsk
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | meulaboh
# Processing Record 42 of Set 3 | bengkulu
# Processing Record 43 of Set 3 | college
# Processing Record 44 of Set 3 | dimapur
# Processing Record 45 of Set 3 | shihezi
# Processing Record 46 of Set 3 | comodoro rivadavia
# Processing Record 47 of Set 3 | alice springs
# Processing Record 48 of Set 3 | alofi
# Processing Record 49 of Set 3 | pryazha
# Processing Record 50 of Set 3 | katsuura
# Processing Record 1 of Set 4 | tura
# Processing Record 2 of Set 4 | wageningen
# Processing Record 3 of Set 4 | ginir
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 4 | soure
# Processing Record 6 of Set 4 | arbuzynka
# Processing Record 7 of Set 4 | santa maria
# Processing Record 8 of Set 4 | bajil
# Processing Record 9 of Set 4 | yambio
# Processing Record 10 of Set 4 | inhambane
# Processing Record 11 of Set 4 | nipawin
# Processing Record 12 of Set 4 | lyngseidet
# Processing Record 13 of Set 4 | sao joao do paraiso
# Processing Record 14 of Set 4 | champerico
# Processing Record 15 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 4 | jumla
# Processing Record 17 of Set 4 | sumbe
# Processing Record 18 of Set 4 | castro
# Processing Record 19 of Set 4 | singaraja
# Processing Record 20 of Set 4 | cabo san lucas
# Processing Record 21 of Set 4 | buala
# Processing Record 22 of Set 4 | dingle
# Processing Record 23 of Set 4 | tautira
# Processing Record 24 of Set 4 | menongue
# Processing Record 25 of Set 4 | yueyang
# Processing Record 26 of Set 4 | hilo
# Processing Record 27 of Set 4 | yumen
# Processing Record 28 of Set 4 | belmonte
# Processing Record 29 of Set 4 | kaniama
# Processing Record 30 of Set 4 | hithadhoo
# Processing Record 31 of Set 4 | laguna
# Processing Record 32 of Set 4 | bethel
# Processing Record 33 of Set 4 | vilcun
# Processing Record 34 of Set 4 | kautokeino
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | zhigansk
# Processing Record 37 of Set 4 | thinadhoo
# Processing Record 38 of Set 4 | burica
# City not found. Skipping...
# Processing Record 39 of Set 4 | cayenne
# Processing Record 40 of Set 4 | sabinopolis
# Processing Record 41 of Set 4 | barbacoas
# Processing Record 42 of Set 4 | asfi
# Processing Record 43 of Set 4 | puerto ayacucho
# Processing Record 44 of Set 4 | kokopo
# Processing Record 45 of Set 4 | port alfred
# Processing Record 46 of Set 4 | ishigaki
# Processing Record 47 of Set 4 | kisangani
# Processing Record 48 of Set 4 | taoudenni
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | brindisi
# Processing Record 1 of Set 5 | airai
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | codrington
# Processing Record 4 of Set 5 | khani
# Processing Record 5 of Set 5 | alugan
# Processing Record 6 of Set 5 | mar del plata
# Processing Record 7 of Set 5 | coutances
# Processing Record 8 of Set 5 | oksfjord
# Processing Record 9 of Set 5 | oranjemund
# Processing Record 10 of Set 5 | vestmanna
# Processing Record 11 of Set 5 | vila velha
# Processing Record 12 of Set 5 | havoysund
# Processing Record 13 of Set 5 | bonavista
# Processing Record 14 of Set 5 | denpasar
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | port elizabeth
# Processing Record 17 of Set 5 | pacific grove
# Processing Record 18 of Set 5 | kuli
# Processing Record 19 of Set 5 | guacimo
# Processing Record 20 of Set 5 | palana
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | lethem
# Processing Record 24 of Set 5 | tabat
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 5 | inongo
# Processing Record 28 of Set 5 | buka
# Processing Record 29 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | lompoc
# Processing Record 32 of Set 5 | dikson
# Processing Record 33 of Set 5 | sakakah
# Processing Record 34 of Set 5 | grand gaube
# Processing Record 35 of Set 5 | puro
# Processing Record 36 of Set 5 | komsomolskiy
# Processing Record 37 of Set 5 | batsfjord
# Processing Record 38 of Set 5 | lindas
# Processing Record 39 of Set 5 | honningsvag
# Processing Record 40 of Set 5 | chapais
# Processing Record 41 of Set 5 | praia
# Processing Record 42 of Set 5 | kununurra
# Processing Record 43 of Set 5 | kahului
# Processing Record 44 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 5 | aripuana
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | panguna
# Processing Record 48 of Set 5 | merauke
# Processing Record 49 of Set 5 | abu dhabi
# Processing Record 50 of Set 5 | pauini
# Processing Record 1 of Set 6 | moose jaw
# Processing Record 2 of Set 6 | sa kaeo
# Processing Record 3 of Set 6 | slobodskoy
# Processing Record 4 of Set 6 | ketchikan
# Processing Record 5 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 6 of Set 6 | san rafael del sur
# Processing Record 7 of Set 6 | glens falls
# Processing Record 8 of Set 6 | avera
# Processing Record 9 of Set 6 | taltal
# Processing Record 10 of Set 6 | longyearbyen
# Processing Record 11 of Set 6 | borba
# Processing Record 12 of Set 6 | taraza
# Processing Record 13 of Set 6 | taunggyi
# Processing Record 14 of Set 6 | kodiak
# Processing Record 15 of Set 6 | grenada
# Processing Record 16 of Set 6 | latur
# Processing Record 17 of Set 6 | manokwari
# Processing Record 18 of Set 6 | saint-francois
# Processing Record 19 of Set 6 | severo-kurilsk
# Processing Record 20 of Set 6 | ahipara
# Processing Record 21 of Set 6 | gimli
# Processing Record 22 of Set 6 | rancho palos verdes
# Processing Record 23 of Set 6 | coruripe
# Processing Record 24 of Set 6 | billings
# Processing Record 25 of Set 6 | tipuani
# Processing Record 26 of Set 6 | jaciara
# Processing Record 27 of Set 6 | ipameri
# Processing Record 28 of Set 6 | cassilandia
# Processing Record 29 of Set 6 | alexandria
# Processing Record 30 of Set 6 | fort nelson
# Processing Record 31 of Set 6 | nueva gerona
# Processing Record 32 of Set 6 | pyu
# Processing Record 33 of Set 6 | chipinge
# Processing Record 34 of Set 6 | maceio
# Processing Record 35 of Set 6 | provideniya
# Processing Record 36 of Set 6 | korfovskiy
# Processing Record 37 of Set 6 | saint-pierre
# Processing Record 38 of Set 6 | neapolis
# Processing Record 39 of Set 6 | pak phanang
# Processing Record 40 of Set 6 | leningradskiy
# Processing Record 41 of Set 6 | maragogi
# Processing Record 42 of Set 6 | naze
# Processing Record 43 of Set 6 | pisco
# Processing Record 44 of Set 6 | luderitz
# Processing Record 45 of Set 6 | quatre cocos
# Processing Record 46 of Set 6 | cairns
# Processing Record 47 of Set 6 | vienne
# Processing Record 48 of Set 6 | cherskiy
# Processing Record 49 of Set 6 | bara
# Processing Record 50 of Set 6 | ambon
# Processing Record 1 of Set 7 | okhotsk
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | bandarbeyla
# Processing Record 4 of Set 7 | homer
# Processing Record 5 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 7 | svetlyy
# Processing Record 7 of Set 7 | kamien pomorski
# Processing Record 8 of Set 7 | vangaindrano
# Processing Record 9 of Set 7 | la ferte-bernard
# Processing Record 10 of Set 7 | pevek
# Processing Record 11 of Set 7 | kerema
# Processing Record 12 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 7 | ostrovnoy
# Processing Record 14 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 7 | mogok
# Processing Record 16 of Set 7 | ericeira
# Processing Record 17 of Set 7 | liverpool
# Processing Record 18 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 19 of Set 7 | vostok
# Processing Record 20 of Set 7 | asyut
# Processing Record 21 of Set 7 | concordia
# Processing Record 22 of Set 7 | pahrump
# Processing Record 23 of Set 7 | vercelli
# Processing Record 24 of Set 7 | valdivia
# Processing Record 25 of Set 7 | lodi
# Processing Record 26 of Set 7 | baruun-urt
# Processing Record 27 of Set 7 | tateyama
# Processing Record 28 of Set 7 | norman wells
# Processing Record 29 of Set 7 | neiafu
# Processing Record 30 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 7 | ukiah
# Processing Record 32 of Set 7 | souris
# Processing Record 33 of Set 7 | tuatapere
# Processing Record 34 of Set 7 | gadung
# Processing Record 35 of Set 7 | onega
# Processing Record 36 of Set 7 | belyy yar
# Processing Record 37 of Set 7 | nioro
# Processing Record 38 of Set 7 | saskylakh
# Processing Record 39 of Set 7 | rawson
# Processing Record 40 of Set 7 | nhulunbuy
# Processing Record 41 of Set 7 | port blair
# Processing Record 42 of Set 7 | pittsfield
# Processing Record 43 of Set 7 | huarmey
# Processing Record 44 of Set 7 | whitehorse
# Processing Record 45 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 7 | bahia blanca
# Processing Record 47 of Set 7 | srednekolymsk
# Processing Record 48 of Set 7 | parakan
# Processing Record 49 of Set 7 | nemuro
# Processing Record 50 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 8 | sobolevo
# Processing Record 2 of Set 8 | mirnyy
# Processing Record 3 of Set 8 | trapani
# Processing Record 4 of Set 8 | arman
# Processing Record 5 of Set 8 | teguldet
# Processing Record 6 of Set 8 | pitimbu
# Processing Record 7 of Set 8 | maniitsoq
# Processing Record 8 of Set 8 | ixtapa
# Processing Record 9 of Set 8 | jutai
# Processing Record 10 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 8 | san felipe
# Processing Record 12 of Set 8 | yelniki
# Processing Record 13 of Set 8 | acheng
# Processing Record 14 of Set 8 | hovd
# Processing Record 15 of Set 8 | savelugu
# Processing Record 16 of Set 8 | chesham
# Processing Record 17 of Set 8 | sisimiut
# Processing Record 18 of Set 8 | lewistown
# Processing Record 19 of Set 8 | dongsheng
# Processing Record 20 of Set 8 | vila franca do campo
# Processing Record 21 of Set 8 | umm kaddadah
# Processing Record 22 of Set 8 | watsa
# Processing Record 23 of Set 8 | port loko
# Processing Record 24 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 8 | las vegas
# Processing Record 26 of Set 8 | paciran
# Processing Record 27 of Set 8 | khatanga
# Processing Record 28 of Set 8 | yerbogachen
# Processing Record 29 of Set 8 | sibolga
# Processing Record 30 of Set 8 | paita
# Processing Record 31 of Set 8 | hay river
# Processing Record 32 of Set 8 | nantucket
# Processing Record 33 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 8 | port moresby
# Processing Record 35 of Set 8 | buchanan
# Processing Record 36 of Set 8 | georgiyevka
# Processing Record 37 of Set 8 | bayshore gardens
# Processing Record 38 of Set 8 | caluquembe
# Processing Record 39 of Set 8 | ambovombe
# Processing Record 40 of Set 8 | yulara
# Processing Record 41 of Set 8 | bud
# Processing Record 42 of Set 8 | acapulco
# Processing Record 43 of Set 8 | atar
# Processing Record 44 of Set 8 | cooma
# Processing Record 45 of Set 8 | tingi
# Processing Record 46 of Set 8 | tigil
# Processing Record 47 of Set 8 | morant bay
# Processing Record 48 of Set 8 | uruacu
# Processing Record 49 of Set 8 | acaponeta
# Processing Record 50 of Set 8 | tecoanapa
# Processing Record 1 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 9 | olafsvik
# Processing Record 3 of Set 9 | sinnamary
# Processing Record 4 of Set 9 | kaeo
# Processing Record 5 of Set 9 | goderich
# Processing Record 6 of Set 9 | nishihara
# Processing Record 7 of Set 9 | kamenka
# Processing Record 8 of Set 9 | uttarkashi
# Processing Record 9 of Set 9 | karasjok
# Processing Record 10 of Set 9 | san quintin
# Processing Record 11 of Set 9 | kabalo
# Processing Record 12 of Set 9 | hami
# Processing Record 13 of Set 9 | calabozo
# Processing Record 14 of Set 9 | killybegs
# Processing Record 15 of Set 9 | hamilton
# Processing Record 16 of Set 9 | semey
# Processing Record 17 of Set 9 | san andres
# Processing Record 18 of Set 9 | erenhot
# Processing Record 19 of Set 9 | cozumel
# Processing Record 20 of Set 9 | kieta
# Processing Record 21 of Set 9 | dulce nombre de culmi
# Processing Record 22 of Set 9 | mandalgovi
# Processing Record 23 of Set 9 | orlik
# Processing Record 24 of Set 9 | husavik
# Processing Record 25 of Set 9 | holme
# Processing Record 26 of Set 9 | te anau
# Processing Record 27 of Set 9 | chauk
# Processing Record 28 of Set 9 | kalinovskaya
# Processing Record 29 of Set 9 | brovary
# Processing Record 30 of Set 9 | hvammstangi
# City not found. Skipping...
# Processing Record 31 of Set 9 | winfield
# Processing Record 32 of Set 9 | mutoko
# Processing Record 33 of Set 9 | isangel
# Processing Record 34 of Set 9 | villefranche-de-rouergue
# Processing Record 35 of Set 9 | coahuayana
# Processing Record 36 of Set 9 | korla
# Processing Record 37 of Set 9 | niigata
# Processing Record 38 of Set 9 | manado
# Processing Record 39 of Set 9 | east london
# Processing Record 40 of Set 9 | makakilo city
# Processing Record 41 of Set 9 | kysyl-syr
# Processing Record 42 of Set 9 | griffith
# Processing Record 43 of Set 9 | freeport
# Processing Record 44 of Set 9 | hofn
# Processing Record 45 of Set 9 | angoche
# Processing Record 46 of Set 9 | port-gentil
# Processing Record 47 of Set 9 | shambu
# Processing Record 48 of Set 9 | qaqortoq
# Processing Record 49 of Set 9 | zambezi
# Processing Record 50 of Set 9 | phalodi
# Processing Record 1 of Set 10 | marawi
# Processing Record 2 of Set 10 | dzaoudzi
# Processing Record 3 of Set 10 | khandyga
# Processing Record 4 of Set 10 | chase
# Processing Record 5 of Set 10 | ponta do sol
# Processing Record 6 of Set 10 | yar-sale
# Processing Record 7 of Set 10 | mezen
# Processing Record 8 of Set 10 | roma
# Processing Record 9 of Set 10 | perth
# Processing Record 10 of Set 10 | georgiyevskoye
# Processing Record 11 of Set 10 | churachandpur
# Processing Record 12 of Set 10 | abha
# Processing Record 13 of Set 10 | upata
# Processing Record 14 of Set 10 | broken hill
# Processing Record 15 of Set 10 | sembakung
# Processing Record 16 of Set 10 | oistins
# Processing Record 17 of Set 10 | hirara
# Processing Record 18 of Set 10 | beringovskiy
# Processing Record 19 of Set 10 | isla mujeres
# Processing Record 20 of Set 10 | pangnirtung
# Processing Record 21 of Set 10 | camacha
# Processing Record 22 of Set 10 | riyadh
# Processing Record 23 of Set 10 | biloela
# Processing Record 24 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 10 | qandala
# Processing Record 26 of Set 10 | norrtalje
# Processing Record 27 of Set 10 | lokosovo
# Processing Record 28 of Set 10 | vaitape
# Processing Record 29 of Set 10 | cururupu
# Processing Record 30 of Set 10 | tilichiki
# Processing Record 31 of Set 10 | mogadishu
# Processing Record 32 of Set 10 | san rafael
# Processing Record 33 of Set 10 | karratha
# Processing Record 34 of Set 10 | udachnyy
# Processing Record 35 of Set 10 | diego de almagro
# Processing Record 36 of Set 10 | ugoofaaru
# Processing Record 37 of Set 10 | praia da vitoria
# Processing Record 38 of Set 10 | takoradi
# Processing Record 39 of Set 10 | state college
# Processing Record 40 of Set 10 | sabirabad
# Processing Record 41 of Set 10 | sao felix do xingu
# Processing Record 42 of Set 10 | kyzyl-mazhalyk
# Processing Record 43 of Set 10 | ola
# Processing Record 44 of Set 10 | north bend
# Processing Record 45 of Set 10 | kruisfontein
# Processing Record 46 of Set 10 | miri
# Processing Record 47 of Set 10 | okoneshnikovo
# Processing Record 48 of Set 10 | coihaique
# Processing Record 49 of Set 10 | montmagny
# Processing Record 50 of Set 10 | motygino
# Processing Record 1 of Set 11 | atasu
# Processing Record 2 of Set 11 | kandalaksha
# Processing Record 3 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 11 | biltine
# Processing Record 5 of Set 11 | tuscaloosa
# Processing Record 6 of Set 11 | lerik
# Processing Record 7 of Set 11 | lavrentiya
# Processing Record 8 of Set 11 | wladyslawowo
# Processing Record 9 of Set 11 | colesberg
# Processing Record 10 of Set 11 | puerto colombia
# Processing Record 11 of Set 11 | goundam
# Processing Record 12 of Set 11 | saint-joseph
# Processing Record 13 of Set 11 | santa isabel do rio negro
# Processing Record 14 of Set 11 | namatanai
# Processing Record 15 of Set 11 | play cu
# City not found. Skipping...
# Processing Record 16 of Set 11 | sete lagoas
# Processing Record 17 of Set 11 | daru
# Processing Record 18 of Set 11 | myskhako
# Processing Record 19 of Set 11 | karaton
# Processing Record 20 of Set 11 | shingu
# Processing Record 21 of Set 11 | peringat
# Processing Record 22 of Set 11 | keflavik
# Processing Record 23 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 24 of Set 11 | hommelvik
# Processing Record 25 of Set 11 | vao
# Processing Record 26 of Set 11 | jinka
# Processing Record 27 of Set 11 | saint-ambroise
# Processing Record 28 of Set 11 | omboue
# Processing Record 29 of Set 11 | jabinyanah
# Processing Record 30 of Set 11 | heihe
# Processing Record 31 of Set 11 | zonguldak
# Processing Record 32 of Set 11 | polunochnoye
# Processing Record 33 of Set 11 | del rio
# Processing Record 34 of Set 11 | finschhafen
# Processing Record 35 of Set 11 | jiuquan
# Processing Record 36 of Set 11 | pindiga
# Processing Record 37 of Set 11 | thornbury
# Processing Record 38 of Set 11 | baraboo
# Processing Record 39 of Set 11 | terney
# Processing Record 40 of Set 11 | grindavik
# Processing Record 41 of Set 11 | reitz
# Processing Record 42 of Set 11 | qasigiannguit
# Processing Record 43 of Set 11 | rio cuarto
# Processing Record 44 of Set 11 | chabahar
# Processing Record 45 of Set 11 | estelle
# Processing Record 46 of Set 11 | berlevag
# Processing Record 47 of Set 11 | half moon bay
# Processing Record 48 of Set 11 | ewa beach
# Processing Record 49 of Set 11 | ouegoa
# Processing Record 50 of Set 11 | carlisle
# Processing Record 1 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 12 | aktau
# Processing Record 3 of Set 12 | phalaborwa
# Processing Record 4 of Set 12 | sao filipe
# Processing Record 5 of Set 12 | bathsheba
# Processing Record 6 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 12 | dryden
# Processing Record 8 of Set 12 | monrovia
# Processing Record 9 of Set 12 | cap malheureux
# Processing Record 10 of Set 12 | saint-augustin
# Processing Record 11 of Set 12 | lira
# Processing Record 12 of Set 12 | kuybyshevo
# Processing Record 13 of Set 12 | urumqi
# Processing Record 14 of Set 12 | bella union
# Processing Record 15 of Set 12 | moron
# Processing Record 16 of Set 12 | amapa
# Processing Record 17 of Set 12 | huanan
# Processing Record 18 of Set 12 | margate
# Processing Record 19 of Set 12 | behshahr
# Processing Record 20 of Set 12 | kuandian
# Processing Record 21 of Set 12 | bitung
# Processing Record 22 of Set 12 | kalmunai
# Processing Record 23 of Set 12 | sur
# Processing Record 24 of Set 12 | great bend
# Processing Record 25 of Set 12 | williston
# Processing Record 26 of Set 12 | high level
# Processing Record 27 of Set 12 | yongan
# Processing Record 28 of Set 12 | kananga
# Processing Record 29 of Set 12 | teya
# Processing Record 30 of Set 12 | eminabad
# Processing Record 31 of Set 12 | leh
# Processing Record 32 of Set 12 | gayeri
# Processing Record 33 of Set 12 | cherdyn
# Processing Record 34 of Set 12 | kudahuvadhoo
# Processing Record 35 of Set 12 | torbat-e jam
# Processing Record 36 of Set 12 | puerto escondido
# Processing Record 37 of Set 12 | nara
# Processing Record 38 of Set 12 | cabra
# Processing Record 39 of Set 12 | yakeshi
# Processing Record 40 of Set 12 | pointe-noire
# Processing Record 41 of Set 12 | touba
# Processing Record 42 of Set 12 | horadiz
# Processing Record 43 of Set 12 | shirpur
# Processing Record 44 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 45 of Set 12 | urucara
# Processing Record 46 of Set 12 | mmabatho
# Processing Record 47 of Set 12 | iringa
# Processing Record 48 of Set 12 | dauriya
# Processing Record 49 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 50 of Set 12 | havre-saint-pierre
# Processing Record 1 of Set 13 | razole
# Processing Record 2 of Set 13 | devonport
# Processing Record 3 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 4 of Set 13 | narsaq
# Processing Record 5 of Set 13 | ibra
# Processing Record 6 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 13 | gat
# Processing Record 8 of Set 13 | tongliao
# Processing Record 9 of Set 13 | shawnee
# Processing Record 10 of Set 13 | malchevskaya
# Processing Record 11 of Set 13 | ekibastuz
# Processing Record 12 of Set 13 | tsabong
# Processing Record 13 of Set 13 | ajdabiya
# Processing Record 14 of Set 13 | chulym
# Processing Record 15 of Set 13 | aklavik
# Processing Record 16 of Set 13 | swellendam
# Processing Record 17 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 18 of Set 13 | evensk
# Processing Record 19 of Set 13 | umm lajj
# Processing Record 20 of Set 13 | magadan
# Processing Record 21 of Set 13 | miura
# Processing Record 22 of Set 13 | bend
# Processing Record 23 of Set 13 | tabuk
# Processing Record 24 of Set 13 | severnyy
# Processing Record 25 of Set 13 | bugarama
# Processing Record 26 of Set 13 | paamiut
# Processing Record 27 of Set 13 | farah
# Processing Record 28 of Set 13 | port hardy
# Processing Record 29 of Set 13 | yanam
# Processing Record 30 of Set 13 | sillod
# Processing Record 31 of Set 13 | san pedro
# Processing Record 32 of Set 13 | marrakesh
# Processing Record 33 of Set 13 | betare oya
# Processing Record 34 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 35 of Set 13 | poum
# Processing Record 36 of Set 13 | umirim
# Processing Record 37 of Set 13 | hualmay
# Processing Record 38 of Set 13 | porto novo
# Processing Record 39 of Set 13 | arona
# Processing Record 40 of Set 13 | vestmannaeyjar
# Processing Record 41 of Set 13 | laela
# Processing Record 42 of Set 13 | zhezkazgan
# Processing Record 43 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 13 | kashi
# Processing Record 45 of Set 13 | lasa
# Processing Record 46 of Set 13 | mayo
# Processing Record 47 of Set 13 | balykshi
# City not found. Skipping...
# Processing Record 48 of Set 13 | maridi
# Processing Record 49 of Set 13 | bastia
# Processing Record 50 of Set 13 | renqiu
# Processing Record 1 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 2 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 14 | ducheng
# Processing Record 4 of Set 14 | gibsons
# Processing Record 5 of Set 14 | channel-port aux basques
# Processing Record 6 of Set 14 | tevaitoa
# Processing Record 7 of Set 14 | kenai
# Processing Record 8 of Set 14 | petropavl
# Processing Record 9 of Set 14 | bodoco
# City not found. Skipping...
# Processing Record 10 of Set 14 | livingstonia
# Processing Record 11 of Set 14 | goure
# Processing Record 12 of Set 14 | sanmenxia
# Processing Record 13 of Set 14 | partapur
# Processing Record 14 of Set 14 | kulhudhuffushi
# Processing Record 15 of Set 14 | buraydah
# Processing Record 16 of Set 14 | hondo
# Processing Record 17 of Set 14 | loreto
# Processing Record 18 of Set 14 | palencia
# Processing Record 19 of Set 14 | monterey
# Processing Record 20 of Set 14 | lerwick
# Processing Record 21 of Set 14 | vysokogornyy
# Processing Record 22 of Set 14 | amuntai
# Processing Record 23 of Set 14 | juba
# Processing Record 24 of Set 14 | quelimane
# Processing Record 25 of Set 14 | kropotkin
# Processing Record 26 of Set 14 | saint-leu
# Processing Record 27 of Set 14 | romitan
# Processing Record 28 of Set 14 | veraval
# Processing Record 29 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 30 of Set 14 | kembe
# Processing Record 31 of Set 14 | meadow lake
# Processing Record 32 of Set 14 | barbosa ferraz
# Processing Record 33 of Set 14 | riberalta
# Processing Record 34 of Set 14 | port-cartier
# Processing Record 35 of Set 14 | pemangkat
# Processing Record 36 of Set 14 | pecos
# Processing Record 37 of Set 14 | fujin
# Processing Record 38 of Set 14 | abeche
# Processing Record 39 of Set 14 | rio grande
# Processing Record 40 of Set 14 | lazaro cardenas
# Processing Record 41 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 14 | tokmak
# Processing Record 43 of Set 14 | jibuti
# Processing Record 44 of Set 14 | ropczyce
# Processing Record 45 of Set 14 | chernyshevskiy
# Processing Record 46 of Set 14 | umm jarr
# City not found. Skipping...
# Processing Record 47 of Set 14 | paptalaya
# Processing Record 48 of Set 14 | anadyr
# Processing Record 49 of Set 14 | fairbanks
# Processing Record 50 of Set 14 | chok chai
# Processing Record 1 of Set 15 | sembe
# Processing Record 2 of Set 15 | krasnoarmeyskiy
# Processing Record 3 of Set 15 | samarai
# Processing Record 4 of Set 15 | boa vista
# Processing Record 5 of Set 15 | flinders
# Processing Record 6 of Set 15 | ravar
# Processing Record 7 of Set 15 | mattawa
# Processing Record 8 of Set 15 | abonnema
# Processing Record 9 of Set 15 | mamakan
# Processing Record 10 of Set 15 | kharan
# Processing Record 11 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 15 | macau
# Processing Record 13 of Set 15 | sitka
# Processing Record 14 of Set 15 | nabire
# Processing Record 15 of Set 15 | taksimo
# Processing Record 16 of Set 15 | kurilsk
# Processing Record 17 of Set 15 | padang
# Processing Record 18 of Set 15 | moindou
# Processing Record 19 of Set 15 | havelock
# Processing Record 20 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 15 | auki
# Processing Record 22 of Set 15 | centralia
# Processing Record 23 of Set 15 | garowe
# Processing Record 24 of Set 15 | pokrovsk
# Processing Record 25 of Set 15 | labuhan
# Processing Record 26 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 15 | sharjah
# Processing Record 28 of Set 15 | harlingen
# Processing Record 29 of Set 15 | sterling
# Processing Record 30 of Set 15 | dom pedrito
# Processing Record 31 of Set 15 | ishinomaki
# Processing Record 32 of Set 15 | gizo
# Processing Record 33 of Set 15 | tual
# Processing Record 34 of Set 15 | hede
# Processing Record 35 of Set 15 | minsk mazowiecki
# Processing Record 36 of Set 15 | payakumbuh
# Processing Record 37 of Set 15 | rodrigues alves
# Processing Record 38 of Set 15 | martapura
# Processing Record 39 of Set 15 | lata
# Processing Record 40 of Set 15 | verkhnevilyuysk
# Processing Record 41 of Set 15 | carndonagh
# Processing Record 42 of Set 15 | linfen
# Processing Record 43 of Set 15 | batangafo
# Processing Record 44 of Set 15 | brae
# Processing Record 45 of Set 15 | camopi
# Processing Record 46 of Set 15 | medea
# Processing Record 47 of Set 15 | yeppoon
# Processing Record 48 of Set 15 | maseru
# Processing Record 49 of Set 15 | smolenka
# Processing Record 50 of Set 15 | aswan
# Processing Record 1 of Set 16 | matay
# Processing Record 2 of Set 16 | ndele
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Nome  64.50 -165.41     48.20        87          20        3.74
# 1       Avarua -21.21 -159.78     71.60        78          92       12.75
# 2      Lubango -14.92   13.49     67.33        23           1        4.72
# 3         Soyo  -6.13   12.37     72.59        81          28       10.67
# 4      Ushuaia -54.80  -68.30     35.60        87          75       16.11
# 5     Hermanus -34.42   19.23     51.01        77          94       12.24
# 6    Carnarvon -24.87  113.63     62.60        88          53       10.29
# 7      Mataura -46.19  168.86     43.68        76         100        4.34
# 8  Clyde River  70.47  -68.59     59.00        62          75       13.87
# 9  Henties Bay -22.12   14.28     60.01        76           0       10.00
#
#   Current Description Country                 Date
# 0          few clouds      US  2020-08-18 16:53:17
# 1          light rain      CK  2020-08-18 16:53:17
# 2           clear sky      AO  2020-08-18 16:53:17
# 3    scattered clouds      AO  2020-08-18 16:53:17
# 4   light shower snow      AR  2020-08-18 16:52:23
# 5     overcast clouds      ZA  2020-08-18 16:53:18
# 6       broken clouds      AU  2020-08-18 16:53:18
# 7     overcast clouds      NZ  2020-08-18 16:53:19
# 8       broken clouds      CA  2020-08-18 16:53:19
# 9           clear sky      NA  2020-08-18 16:53:19

# %%
# Organize the  columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Nome      US  64.50 -165.41     48.20        87          20
# 1       Avarua      CK -21.21 -159.78     71.60        78          92
# 2      Lubango      AO -14.92   13.49     67.33        23           1
# 3         Soyo      AO  -6.13   12.37     72.59        81          28
# 4      Ushuaia      AR -54.80  -68.30     35.60        87          75
# 5     Hermanus      ZA -34.42   19.23     51.01        77          94
# 6    Carnarvon      AU -24.87  113.63     62.60        88          53
# 7      Mataura      NZ -46.19  168.86     43.68        76         100
# 8  Clyde River      CA  70.47  -68.59     59.00        62          75
# 9  Henties Bay      NA -22.12   14.28     60.01        76           0
#
#    Wind Speed Current Description
# 0        3.74          few clouds
# 1       12.75          light rain
# 2        4.72           clear sky
# 3       10.67    scattered clouds
# 4       16.11   light shower snow
# 5       12.24     overcast clouds
# 6       10.29       broken clouds
# 7        4.34     overcast clouds
# 8       13.87       broken clouds
# 9       10.00           clear sky

# %%
# Create and export the final Data Frame into a CSV
city_data__no_date_df.to_csv("Weather_Database/WeatherPy_Database.csv", index_label="City_ID")
