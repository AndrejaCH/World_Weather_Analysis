# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Zipping the pairs in a tuple with zip() function.
lat_lngs = zip(lats, lngs)

# %%
#Unpack zip tuples into a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination using citypy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then append to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count.
len(cities)
# Out:
# 761

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | tilichiki
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | kununurra
# Processing Record 5 of Set 1 | tocopilla
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | lata
# Processing Record 8 of Set 1 | hanstholm
# Processing Record 9 of Set 1 | tymovskoye
# Processing Record 10 of Set 1 | ilulissat
# Processing Record 11 of Set 1 | grand gaube
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | esperance
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | ankang
# Processing Record 18 of Set 1 | yeppoon
# Processing Record 19 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 1 | marevo
# Processing Record 21 of Set 1 | mpanda
# Processing Record 22 of Set 1 | laguna
# Processing Record 23 of Set 1 | cherskiy
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | ola
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | port hawkesbury
# Processing Record 30 of Set 1 | tuatapere
# Processing Record 31 of Set 1 | soyo
# Processing Record 32 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | kloulklubed
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | neiafu
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | thunder bay
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | vilyuysk
# Processing Record 45 of Set 1 | punta alta
# Processing Record 46 of Set 1 | isangel
# Processing Record 47 of Set 1 | hervey bay
# Processing Record 48 of Set 1 | eslov
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | bayamo
# Processing Record 3 of Set 2 | mokhsogollokh
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | hit
# Processing Record 6 of Set 2 | oussouye
# Processing Record 7 of Set 2 | sinnamary
# Processing Record 8 of Set 2 | beringovskiy
# Processing Record 9 of Set 2 | hofn
# Processing Record 10 of Set 2 | atar
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | urubicha
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | sept-iles
# Processing Record 16 of Set 2 | muriwai beach
# Processing Record 17 of Set 2 | chapais
# Processing Record 18 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 19 of Set 2 | albury
# Processing Record 20 of Set 2 | mangla
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | alta floresta
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | nagapattinam
# Processing Record 26 of Set 2 | udomlya
# Processing Record 27 of Set 2 | sakaiminato
# Processing Record 28 of Set 2 | calatayud
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | half moon bay
# Processing Record 31 of Set 2 | caravelas
# Processing Record 32 of Set 2 | petrovac
# Processing Record 33 of Set 2 | ciudad bolivar
# Processing Record 34 of Set 2 | omboue
# Processing Record 35 of Set 2 | balfour
# Processing Record 36 of Set 2 | finschhafen
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | honiara
# Processing Record 40 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 2 | tokzar
# City not found. Skipping...
# Processing Record 42 of Set 2 | iqaluit
# Processing Record 43 of Set 2 | ukiah
# Processing Record 44 of Set 2 | krivosheino
# Processing Record 45 of Set 2 | zhigansk
# Processing Record 46 of Set 2 | igarka
# Processing Record 47 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | iranshahr
# Processing Record 50 of Set 2 | tahta
# Processing Record 1 of Set 3 | tshikapa
# Processing Record 2 of Set 3 | aswan
# Processing Record 3 of Set 3 | valleyview
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | codrington
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | alice springs
# Processing Record 8 of Set 3 | turukhansk
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | tura
# Processing Record 11 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | carmen
# Processing Record 14 of Set 3 | inirida
# Processing Record 15 of Set 3 | gorontalo
# Processing Record 16 of Set 3 | kapuskasing
# Processing Record 17 of Set 3 | te anau
# Processing Record 18 of Set 3 | srednekolymsk
# Processing Record 19 of Set 3 | victoria
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | fortuna
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | shimoda
# Processing Record 27 of Set 3 | husavik
# Processing Record 28 of Set 3 | camalu
# Processing Record 29 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 3 | praya
# Processing Record 31 of Set 3 | radford
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | flin flon
# Processing Record 34 of Set 3 | ahipara
# Processing Record 35 of Set 3 | dikson
# Processing Record 36 of Set 3 | kaspiyskiy
# Processing Record 37 of Set 3 | cheremukhovo
# Processing Record 38 of Set 3 | nanortalik
# Processing Record 39 of Set 3 | richards bay
# Processing Record 40 of Set 3 | soavinandriana
# Processing Record 41 of Set 3 | metu
# Processing Record 42 of Set 3 | lock haven
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | vysokogornyy
# Processing Record 47 of Set 3 | vestmanna
# Processing Record 48 of Set 3 | kavaratti
# Processing Record 49 of Set 3 | ancud
# Processing Record 50 of Set 3 | venice
# Processing Record 1 of Set 4 | joshimath
# Processing Record 2 of Set 4 | ocampo
# Processing Record 3 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 4 | grindavik
# Processing Record 5 of Set 4 | soure
# Processing Record 6 of Set 4 | chengmai
# City not found. Skipping...
# Processing Record 7 of Set 4 | norman wells
# Processing Record 8 of Set 4 | mitu
# Processing Record 9 of Set 4 | houma
# Processing Record 10 of Set 4 | cidreira
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | jiblah
# Processing Record 13 of Set 4 | tucuma
# Processing Record 14 of Set 4 | iluppur
# Processing Record 15 of Set 4 | saint-pierre
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | hsinhua
# City not found. Skipping...
# Processing Record 18 of Set 4 | chuy
# Processing Record 19 of Set 4 | kemi
# Processing Record 20 of Set 4 | punta arenas
# Processing Record 21 of Set 4 | kozhevnikovo
# Processing Record 22 of Set 4 | saint-michel-des-saints
# Processing Record 23 of Set 4 | tasiilaq
# Processing Record 24 of Set 4 | kumluca
# Processing Record 25 of Set 4 | raudeberg
# Processing Record 26 of Set 4 | fairbanks
# Processing Record 27 of Set 4 | oudtshoorn
# Processing Record 28 of Set 4 | goderich
# Processing Record 29 of Set 4 | likasi
# Processing Record 30 of Set 4 | hambantota
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | haines junction
# Processing Record 33 of Set 4 | nome
# Processing Record 34 of Set 4 | gazli
# Processing Record 35 of Set 4 | kyren
# Processing Record 36 of Set 4 | jalu
# Processing Record 37 of Set 4 | silver city
# Processing Record 38 of Set 4 | ribeira grande
# Processing Record 39 of Set 4 | chokurdakh
# Processing Record 40 of Set 4 | nishihara
# Processing Record 41 of Set 4 | hami
# Processing Record 42 of Set 4 | zabol
# Processing Record 43 of Set 4 | ishigaki
# Processing Record 44 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 4 | rancho palos verdes
# Processing Record 46 of Set 4 | nalobikha
# Processing Record 47 of Set 4 | berlevag
# Processing Record 48 of Set 4 | cap malheureux
# Processing Record 49 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 50 of Set 4 | asenovgrad
# Processing Record 1 of Set 5 | beyneu
# Processing Record 2 of Set 5 | roald
# Processing Record 3 of Set 5 | belmonte
# Processing Record 4 of Set 5 | waingapu
# Processing Record 5 of Set 5 | belyy yar
# Processing Record 6 of Set 5 | jamestown
# Processing Record 7 of Set 5 | bengkulu
# Processing Record 8 of Set 5 | bayonet point
# Processing Record 9 of Set 5 | kahului
# Processing Record 10 of Set 5 | colares
# Processing Record 11 of Set 5 | strelka
# Processing Record 12 of Set 5 | zhuhai
# Processing Record 13 of Set 5 | sheregesh
# Processing Record 14 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 5 | kyritz
# Processing Record 16 of Set 5 | san carlos de bariloche
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | yar-sale
# Processing Record 19 of Set 5 | ulaangom
# Processing Record 20 of Set 5 | xinqing
# Processing Record 21 of Set 5 | aleksandrov gay
# Processing Record 22 of Set 5 | pokrovsk
# Processing Record 23 of Set 5 | sao joao da barra
# Processing Record 24 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 5 | sovetskiy
# Processing Record 26 of Set 5 | sibu
# Processing Record 27 of Set 5 | jawhar
# Processing Record 28 of Set 5 | hermanus
# Processing Record 29 of Set 5 | klaksvik
# Processing Record 30 of Set 5 | tiksi
# Processing Record 31 of Set 5 | havre-saint-pierre
# Processing Record 32 of Set 5 | springdale
# Processing Record 33 of Set 5 | shenjiamen
# Processing Record 34 of Set 5 | hope
# Processing Record 35 of Set 5 | guhagar
# Processing Record 36 of Set 5 | bethel
# Processing Record 37 of Set 5 | port hardy
# Processing Record 38 of Set 5 | kangalassy
# Processing Record 39 of Set 5 | la asuncion
# Processing Record 40 of Set 5 | severo-kurilsk
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | sao filipe
# Processing Record 43 of Set 5 | aklavik
# Processing Record 44 of Set 5 | namibe
# Processing Record 45 of Set 5 | santa cruz de tenerife
# Processing Record 46 of Set 5 | thompson
# Processing Record 47 of Set 5 | manokwari
# Processing Record 48 of Set 5 | saumur
# Processing Record 49 of Set 5 | polovinnoye
# Processing Record 50 of Set 5 | ponta do sol
# Processing Record 1 of Set 6 | oneonta
# Processing Record 2 of Set 6 | karpogory
# Processing Record 3 of Set 6 | pavlohrad
# Processing Record 4 of Set 6 | takaka
# Processing Record 5 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 6 | kavieng
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | talas
# Processing Record 9 of Set 6 | havoysund
# Processing Record 10 of Set 6 | lagoa
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | guerrero negro
# Processing Record 13 of Set 6 | teguise
# Processing Record 14 of Set 6 | kokopo
# Processing Record 15 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 6 | airai
# Processing Record 17 of Set 6 | vestmannaeyjar
# Processing Record 18 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 19 of Set 6 | tokmak
# Processing Record 20 of Set 6 | bezhetsk
# Processing Record 21 of Set 6 | mitha tiwana
# Processing Record 22 of Set 6 | koping
# Processing Record 23 of Set 6 | hadejia
# Processing Record 24 of Set 6 | san jose
# Processing Record 25 of Set 6 | kingaroy
# Processing Record 26 of Set 6 | tamandare
# Processing Record 27 of Set 6 | pemberton
# Processing Record 28 of Set 6 | lyngseidet
# Processing Record 29 of Set 6 | pisco
# Processing Record 30 of Set 6 | the valley
# Processing Record 31 of Set 6 | geraldton
# Processing Record 32 of Set 6 | bredasdorp
# Processing Record 33 of Set 6 | takhatgarh
# Processing Record 34 of Set 6 | hammerfest
# Processing Record 35 of Set 6 | kalomo
# City not found. Skipping...
# Processing Record 36 of Set 6 | narsaq
# Processing Record 37 of Set 6 | sturgis
# Processing Record 38 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 6 | touros
# Processing Record 40 of Set 6 | oranjemund
# Processing Record 41 of Set 6 | koszalin
# Processing Record 42 of Set 6 | havre
# Processing Record 43 of Set 6 | romilly-sur-seine
# Processing Record 44 of Set 6 | bolshaya glushitsa
# Processing Record 45 of Set 6 | arlit
# Processing Record 46 of Set 6 | alofi
# Processing Record 47 of Set 6 | nchelenge
# Processing Record 48 of Set 6 | bahia de caraquez
# Processing Record 49 of Set 6 | baikunthpur
# Processing Record 50 of Set 6 | donji komren
# City not found. Skipping...
# Processing Record 1 of Set 7 | qaanaaq
# Processing Record 2 of Set 7 | jurilovca
# Processing Record 3 of Set 7 | saskylakh
# Processing Record 4 of Set 7 | altay
# Processing Record 5 of Set 7 | north battleford
# Processing Record 6 of Set 7 | kodiak
# Processing Record 7 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 7 | goodlettsville
# Processing Record 9 of Set 7 | taoudenni
# Processing Record 10 of Set 7 | mandurah
# Processing Record 11 of Set 7 | la presa
# Processing Record 12 of Set 7 | komsomolskiy
# Processing Record 13 of Set 7 | hof
# Processing Record 14 of Set 7 | hamilton
# Processing Record 15 of Set 7 | chara
# Processing Record 16 of Set 7 | rio grande
# Processing Record 17 of Set 7 | acarau
# Processing Record 18 of Set 7 | port hedland
# Processing Record 19 of Set 7 | saint pete beach
# Processing Record 20 of Set 7 | kamina
# Processing Record 21 of Set 7 | rantepao
# Processing Record 22 of Set 7 | tiznit
# Processing Record 23 of Set 7 | aykhal
# Processing Record 24 of Set 7 | thoen
# Processing Record 25 of Set 7 | langub
# Processing Record 26 of Set 7 | kaitangata
# Processing Record 27 of Set 7 | ostrovnoy
# Processing Record 28 of Set 7 | camacha
# Processing Record 29 of Set 7 | valdivia
# Processing Record 30 of Set 7 | tonekabon
# Processing Record 31 of Set 7 | alyangula
# Processing Record 32 of Set 7 | umm lajj
# Processing Record 33 of Set 7 | mehamn
# Processing Record 34 of Set 7 | ponta delgada
# Processing Record 35 of Set 7 | tevriz
# Processing Record 36 of Set 7 | khash
# Processing Record 37 of Set 7 | yinchuan
# Processing Record 38 of Set 7 | nyurba
# Processing Record 39 of Set 7 | chumikan
# Processing Record 40 of Set 7 | killybegs
# Processing Record 41 of Set 7 | saint-louis
# Processing Record 42 of Set 7 | mahebourg
# Processing Record 43 of Set 7 | manakara
# Processing Record 44 of Set 7 | columbus
# Processing Record 45 of Set 7 | zeya
# Processing Record 46 of Set 7 | okhotsk
# Processing Record 47 of Set 7 | sumbe
# Processing Record 48 of Set 7 | takoradi
# Processing Record 49 of Set 7 | flinders
# Processing Record 50 of Set 7 | soria
# Processing Record 1 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 8 | dyakonovo
# City not found. Skipping...
# Processing Record 3 of Set 8 | nouakchott
# Processing Record 4 of Set 8 | clyde river
# Processing Record 5 of Set 8 | say
# Processing Record 6 of Set 8 | acapulco
# Processing Record 7 of Set 8 | tezu
# Processing Record 8 of Set 8 | high level
# Processing Record 9 of Set 8 | makakilo city
# Processing Record 10 of Set 8 | lyuban
# Processing Record 11 of Set 8 | chimore
# Processing Record 12 of Set 8 | maningrida
# Processing Record 13 of Set 8 | nago
# Processing Record 14 of Set 8 | grootfontein
# Processing Record 15 of Set 8 | botad
# Processing Record 16 of Set 8 | merritt island
# Processing Record 17 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 8 | faanui
# Processing Record 19 of Set 8 | banda aceh
# Processing Record 20 of Set 8 | emirdag
# Processing Record 21 of Set 8 | kaoma
# Processing Record 22 of Set 8 | haverhill
# Processing Record 23 of Set 8 | la sarre
# Processing Record 24 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 25 of Set 8 | verkhnyaya inta
# Processing Record 26 of Set 8 | shubarkuduk
# Processing Record 27 of Set 8 | borba
# Processing Record 28 of Set 8 | lota
# Processing Record 29 of Set 8 | hays
# Processing Record 30 of Set 8 | port augusta
# Processing Record 31 of Set 8 | manchar
# Processing Record 32 of Set 8 | meiganga
# Processing Record 33 of Set 8 | mangai
# Processing Record 34 of Set 8 | mooi river
# City not found. Skipping...
# Processing Record 35 of Set 8 | araouane
# Processing Record 36 of Set 8 | dukat
# Processing Record 37 of Set 8 | fort frances
# Processing Record 38 of Set 8 | dicabisagan
# Processing Record 39 of Set 8 | vardo
# Processing Record 40 of Set 8 | wyszkow
# Processing Record 41 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 8 | jurado
# Processing Record 43 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 44 of Set 8 | bowen
# Processing Record 45 of Set 8 | roebourne
# Processing Record 46 of Set 8 | constantine
# Processing Record 47 of Set 8 | manaus
# Processing Record 48 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 8 | reconquista
# Processing Record 50 of Set 8 | cafelandia
# Processing Record 1 of Set 9 | arica
# Processing Record 2 of Set 9 | visby
# Processing Record 3 of Set 9 | comodoro rivadavia
# Processing Record 4 of Set 9 | ossora
# Processing Record 5 of Set 9 | halvad
# Processing Record 6 of Set 9 | asau
# Processing Record 7 of Set 9 | anderson
# Processing Record 8 of Set 9 | great falls
# Processing Record 9 of Set 9 | waipawa
# Processing Record 10 of Set 9 | tuy hoa
# Processing Record 11 of Set 9 | sistranda
# Processing Record 12 of Set 9 | peno
# Processing Record 13 of Set 9 | cuamba
# Processing Record 14 of Set 9 | lushunkou
# City not found. Skipping...
# Processing Record 15 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 9 | dunedin
# Processing Record 17 of Set 9 | bairiki
# Processing Record 18 of Set 9 | ewa beach
# Processing Record 19 of Set 9 | westport
# Processing Record 20 of Set 9 | souillac
# Processing Record 21 of Set 9 | kupang
# Processing Record 22 of Set 9 | karaton
# Processing Record 23 of Set 9 | mount isa
# Processing Record 24 of Set 9 | san quintin
# Processing Record 25 of Set 9 | paine
# Processing Record 26 of Set 9 | paranhos
# Processing Record 27 of Set 9 | fukue
# Processing Record 28 of Set 9 | leshukonskoye
# Processing Record 29 of Set 9 | san juan de uraba
# Processing Record 30 of Set 9 | anadyr
# Processing Record 31 of Set 9 | karmana
# City not found. Skipping...
# Processing Record 32 of Set 9 | labuhan
# Processing Record 33 of Set 9 | nuevo imperial
# Processing Record 34 of Set 9 | sivaki
# Processing Record 35 of Set 9 | luderitz
# Processing Record 36 of Set 9 | ulladulla
# Processing Record 37 of Set 9 | arroyo
# Processing Record 38 of Set 9 | tsaratanana
# Processing Record 39 of Set 9 | lazaro cardenas
# Processing Record 40 of Set 9 | spoleto
# Processing Record 41 of Set 9 | buraydah
# Processing Record 42 of Set 9 | fomboni
# Processing Record 43 of Set 9 | gushikawa
# Processing Record 44 of Set 9 | orlik
# Processing Record 45 of Set 9 | jibuti
# Processing Record 46 of Set 9 | the pas
# Processing Record 47 of Set 9 | luganville
# Processing Record 48 of Set 9 | lodja
# Processing Record 49 of Set 9 | machiques
# Processing Record 50 of Set 9 | santa cruz
# Processing Record 1 of Set 10 | thisted
# Processing Record 2 of Set 10 | moerai
# Processing Record 3 of Set 10 | rangoon
# Processing Record 4 of Set 10 | foxborough
# Processing Record 5 of Set 10 | bindura
# Processing Record 6 of Set 10 | prince rupert
# Processing Record 7 of Set 10 | sri aman
# Processing Record 8 of Set 10 | lakatoro
# Processing Record 9 of Set 10 | gambissara
# Processing Record 10 of Set 10 | kencong
# Processing Record 11 of Set 10 | rio brilhante
# Processing Record 12 of Set 10 | yatou
# Processing Record 13 of Set 10 | salvador
# Processing Record 14 of Set 10 | dickinson
# Processing Record 15 of Set 10 | nikel
# Processing Record 16 of Set 10 | superior
# Processing Record 17 of Set 10 | latehar
# Processing Record 18 of Set 10 | baculin
# Processing Record 19 of Set 10 | angatuba
# Processing Record 20 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 10 | bac lieu
# Processing Record 22 of Set 10 | ballarat
# Processing Record 23 of Set 10 | russell
# Processing Record 24 of Set 10 | kidal
# Processing Record 25 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 10 | hovd
# Processing Record 27 of Set 10 | nevsehir
# Processing Record 28 of Set 10 | bulgan
# Processing Record 29 of Set 10 | virginia beach
# Processing Record 30 of Set 10 | nabire
# Processing Record 31 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 10 | kaliua
# Processing Record 33 of Set 10 | bundaberg
# Processing Record 34 of Set 10 | daru
# Processing Record 35 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 36 of Set 10 | mount gambier
# Processing Record 37 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 38 of Set 10 | san patricio
# Processing Record 39 of Set 10 | naduvattam
# Processing Record 40 of Set 10 | olafsvik
# Processing Record 41 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 10 | stepnyak
# Processing Record 43 of Set 10 | port blair
# Processing Record 44 of Set 10 | okoneshnikovo
# Processing Record 45 of Set 10 | kudahuvadhoo
# Processing Record 46 of Set 10 | qandala
# Processing Record 47 of Set 10 | kampong thum
# Processing Record 48 of Set 10 | potosi
# Processing Record 49 of Set 10 | berezovyy
# Processing Record 50 of Set 10 | iralaya
# Processing Record 1 of Set 11 | qaqortoq
# Processing Record 2 of Set 11 | portland
# Processing Record 3 of Set 11 | dali
# Processing Record 4 of Set 11 | iquitos
# Processing Record 5 of Set 11 | tabuk
# Processing Record 6 of Set 11 | saint-augustin
# Processing Record 7 of Set 11 | warri
# Processing Record 8 of Set 11 | bogalusa
# Processing Record 9 of Set 11 | sisimiut
# Processing Record 10 of Set 11 | tolaga bay
# Processing Record 11 of Set 11 | kerema
# Processing Record 12 of Set 11 | college
# Processing Record 13 of Set 11 | luxor
# Processing Record 14 of Set 11 | thinadhoo
# Processing Record 15 of Set 11 | fort smith
# Processing Record 16 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 11 | havelock
# Processing Record 19 of Set 11 | bubaque
# Processing Record 20 of Set 11 | shanhetun
# Processing Record 21 of Set 11 | lewiston
# Processing Record 22 of Set 11 | minbu
# Processing Record 23 of Set 11 | nunoa
# Processing Record 24 of Set 11 | matagami
# Processing Record 25 of Set 11 | yima
# Processing Record 26 of Set 11 | evinayong
# Processing Record 27 of Set 11 | cockburn town
# Processing Record 28 of Set 11 | yerbogachen
# Processing Record 29 of Set 11 | khasan
# Processing Record 30 of Set 11 | vila velha
# Processing Record 31 of Set 11 | urengoy
# Processing Record 32 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 33 of Set 11 | highland
# Processing Record 34 of Set 11 | namatanai
# Processing Record 35 of Set 11 | dasoguz
# Processing Record 36 of Set 11 | tungor
# Processing Record 37 of Set 11 | maues
# Processing Record 38 of Set 11 | loiza
# Processing Record 39 of Set 11 | svetlyy
# Processing Record 40 of Set 11 | palmer
# Processing Record 41 of Set 11 | wolmaranstad
# City not found. Skipping...
# Processing Record 42 of Set 11 | arman
# Processing Record 43 of Set 11 | ambon
# Processing Record 44 of Set 11 | pacific grove
# Processing Record 45 of Set 11 | linxia
# Processing Record 46 of Set 11 | martapura
# Processing Record 47 of Set 11 | muroto
# Processing Record 48 of Set 11 | czechowice-dziedzice
# Processing Record 49 of Set 11 | paamiut
# Processing Record 50 of Set 11 | luanda
# Processing Record 1 of Set 12 | taltal
# Processing Record 2 of Set 12 | kramat
# Processing Record 3 of Set 12 | dezful
# Processing Record 4 of Set 12 | leningradskiy
# Processing Record 5 of Set 12 | bonnyville
# Processing Record 6 of Set 12 | juneau
# Processing Record 7 of Set 12 | saint-francois
# Processing Record 8 of Set 12 | banjar
# Processing Record 9 of Set 12 | bay roberts
# Processing Record 10 of Set 12 | ha giang
# Processing Record 11 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 12 | karasburg
# Processing Record 13 of Set 12 | bonthe
# Processing Record 14 of Set 12 | kotido
# Processing Record 15 of Set 12 | liverpool
# Processing Record 16 of Set 12 | hermiston
# Processing Record 17 of Set 12 | ingham
# Processing Record 18 of Set 12 | canar
# Processing Record 19 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 20 of Set 12 | chelmza
# Processing Record 21 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 22 of Set 12 | ayan
# Processing Record 23 of Set 12 | ruteng
# Processing Record 24 of Set 12 | keti bandar
# Processing Record 25 of Set 12 | genhe
# Processing Record 26 of Set 12 | bud
# Processing Record 27 of Set 12 | askino
# Processing Record 28 of Set 12 | norrtalje
# Processing Record 29 of Set 12 | bonavista
# Processing Record 30 of Set 12 | millinocket
# Processing Record 31 of Set 12 | we
# City not found. Skipping...
# Processing Record 32 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 12 | zhezkazgan
# Processing Record 34 of Set 12 | lucatan
# City not found. Skipping...
# Processing Record 35 of Set 12 | bilibino
# Processing Record 36 of Set 12 | totness
# Processing Record 37 of Set 12 | poum
# Processing Record 38 of Set 12 | broome
# Processing Record 39 of Set 12 | lavrentiya
# Processing Record 40 of Set 12 | dengzhou
# Processing Record 41 of Set 12 | krasnyy oktyabr
# Processing Record 42 of Set 12 | umm bab
# Processing Record 43 of Set 12 | plettenberg bay
# Processing Record 44 of Set 12 | santa maria
# Processing Record 45 of Set 12 | suntar
# Processing Record 46 of Set 12 | beatrice
# Processing Record 47 of Set 12 | bathsheba
# Processing Record 48 of Set 12 | madanapalle
# Processing Record 49 of Set 12 | rafraf
# Processing Record 50 of Set 12 | strezhevoy
# Processing Record 1 of Set 13 | bahia honda
# Processing Record 2 of Set 13 | mount pleasant
# Processing Record 3 of Set 13 | rundu
# Processing Record 4 of Set 13 | erzin
# Processing Record 5 of Set 13 | alcudia
# Processing Record 6 of Set 13 | maraa
# Processing Record 7 of Set 13 | andijon
# Processing Record 8 of Set 13 | adrar
# Processing Record 9 of Set 13 | chaa-khol
# City not found. Skipping...
# Processing Record 10 of Set 13 | jaru
# Processing Record 11 of Set 13 | nadym
# Processing Record 12 of Set 13 | hokitika
# Processing Record 13 of Set 13 | canon city
# Processing Record 14 of Set 13 | hohhot
# Processing Record 15 of Set 13 | zhicheng
# Processing Record 16 of Set 13 | sitka
# Processing Record 17 of Set 13 | willowmore
# Processing Record 18 of Set 13 | aldan
# Processing Record 19 of Set 13 | polunochnoye
# Processing Record 20 of Set 13 | tongzhou
# Processing Record 21 of Set 13 | shelburne
# Processing Record 22 of Set 13 | cayenne
# Processing Record 23 of Set 13 | nylstroom
# City not found. Skipping...
# Processing Record 24 of Set 13 | korla
# Processing Record 25 of Set 13 | neepawa
# Processing Record 26 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 13 | pevek
# Processing Record 28 of Set 13 | exeter
# Processing Record 29 of Set 13 | puerto quijarro
# Processing Record 30 of Set 13 | dondo
# Processing Record 31 of Set 13 | evensk
# Processing Record 32 of Set 13 | ambositra
# Processing Record 33 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 34 of Set 13 | muisne
# Processing Record 35 of Set 13 | sidney
# Processing Record 36 of Set 13 | portsmouth
# Processing Record 37 of Set 13 | presidente dutra
# Processing Record 38 of Set 13 | male
# Processing Record 39 of Set 13 | sieghartskirchen
# Processing Record 40 of Set 13 | antalaha
# Processing Record 41 of Set 13 | ayaviri
# Processing Record 42 of Set 13 | mindelo
# Processing Record 43 of Set 13 | riosucio
# Processing Record 44 of Set 13 | tombouctou
# Processing Record 45 of Set 13 | qasigiannguit
# Processing Record 46 of Set 13 | galesong
# Processing Record 47 of Set 13 | cozumel
# Processing Record 48 of Set 13 | coihaique
# Processing Record 49 of Set 13 | nikolayevsk-na-amure
# Processing Record 50 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 1 of Set 14 | quatre cocos
# Processing Record 2 of Set 14 | jaromerice nad rokytnou
# Processing Record 3 of Set 14 | casino
# Processing Record 4 of Set 14 | tahoua
# Processing Record 5 of Set 14 | yulara
# Processing Record 6 of Set 14 | lingao
# Processing Record 7 of Set 14 | adre
# Processing Record 8 of Set 14 | moose factory
# Processing Record 9 of Set 14 | along
# Processing Record 10 of Set 14 | kasungu
# Processing Record 11 of Set 14 | gazanjyk
# Processing Record 12 of Set 14 | tukrah
# Processing Record 13 of Set 14 | sao raimundo das mangabeiras
# Processing Record 14 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 15 of Set 14 | marsa matruh
# Processing Record 16 of Set 14 | algiers
# Processing Record 17 of Set 14 | gondanglegi
# Processing Record 18 of Set 14 | dingle
# Processing Record 19 of Set 14 | tottori
# Processing Record 20 of Set 14 | tsiroanomandidy
# Processing Record 21 of Set 14 | timra
# Processing Record 22 of Set 14 | kedougou
# Processing Record 23 of Set 14 | zagon
# Processing Record 24 of Set 14 | viedma
# Processing Record 25 of Set 14 | sungaipenuh
# Processing Record 26 of Set 14 | misratah
# Processing Record 27 of Set 14 | ust-tsilma
# Processing Record 28 of Set 14 | talara
# Processing Record 29 of Set 14 | bouza
# Processing Record 30 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 31 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 14 | marquette
# Processing Record 33 of Set 14 | mandan
# Processing Record 34 of Set 14 | constitucion
# Processing Record 35 of Set 14 | lumut
# Processing Record 36 of Set 14 | sao desiderio
# Processing Record 37 of Set 14 | saint anthony
# Processing Record 38 of Set 14 | sawakin
# Processing Record 39 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 14 | det udom
# Processing Record 41 of Set 14 | kropachevo
# Processing Record 42 of Set 14 | praia da vitoria
# Processing Record 43 of Set 14 | kysyl-syr
# Processing Record 44 of Set 14 | hay river
# Processing Record 45 of Set 14 | oktyabrskiy
# Processing Record 46 of Set 14 | esmeraldas
# Processing Record 47 of Set 14 | zyryanka
# Processing Record 48 of Set 14 | guangyuan
# Processing Record 49 of Set 14 | poronaysk
# Processing Record 50 of Set 14 | zachary
# Processing Record 1 of Set 15 | straumen
# Processing Record 2 of Set 15 | mittagong
# Processing Record 3 of Set 15 | jumla
# Processing Record 4 of Set 15 | mecca
# Processing Record 5 of Set 15 | allende
# Processing Record 6 of Set 15 | ulaanbaatar
# Processing Record 7 of Set 15 | san juan
# Processing Record 8 of Set 15 | bela
# Processing Record 9 of Set 15 | tayshet
# Processing Record 10 of Set 15 | indramayu
# Processing Record 11 of Set 15 | vanavara
# Processing Record 12 of Set 15 | borlange
# City not found. Skipping...
# Processing Record 13 of Set 15 | qaracala
# Processing Record 14 of Set 15 | carroll
# Processing Record 15 of Set 15 | alzamay
# Processing Record 16 of Set 15 | mareeba
# Processing Record 17 of Set 15 | vostok
# Processing Record 18 of Set 15 | harrison
# Processing Record 19 of Set 15 | coshocton
# Processing Record 20 of Set 15 | hobyo
# Processing Record 21 of Set 15 | torit
# Processing Record 22 of Set 15 | rawson
# Processing Record 23 of Set 15 | aksu
# Processing Record 24 of Set 15 | sorland
# Processing Record 25 of Set 15 | wanaka
# Processing Record 26 of Set 15 | antofagasta
# Processing Record 27 of Set 15 | katsuura
# Processing Record 28 of Set 15 | hutchinson
# Processing Record 29 of Set 15 | vilkaviskis
# Processing Record 30 of Set 15 | balta
# Processing Record 31 of Set 15 | lieksa
# Processing Record 32 of Set 15 | cao bang
# Processing Record 33 of Set 15 | bandarbeyla
# Processing Record 34 of Set 15 | smolenka
# Processing Record 35 of Set 15 | tonj
# Processing Record 36 of Set 15 | bardiyah
# Processing Record 37 of Set 15 | yumen
# Processing Record 38 of Set 15 | kieta
# Processing Record 39 of Set 15 | sechura
# Processing Record 40 of Set 15 | foz
# Processing Record 41 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 42 of Set 15 | manado
# Processing Record 43 of Set 15 | gubkinskiy
# Processing Record 44 of Set 15 | rio cuarto
# Processing Record 45 of Set 15 | yamethin
# Processing Record 46 of Set 15 | hawkesbury
# Processing Record 47 of Set 15 | buala
# Processing Record 48 of Set 15 | dzaoudzi
# Processing Record 49 of Set 15 | saurimo
# Processing Record 50 of Set 15 | kimbe
# Processing Record 1 of Set 16 | koltsovo
# Processing Record 2 of Set 16 | zavodouspenskoye
# Processing Record 3 of Set 16 | yaan
# Processing Record 4 of Set 16 | shigony
# Processing Record 5 of Set 16 | nova borova
# Processing Record 6 of Set 16 | camana
# Processing Record 7 of Set 16 | tommot
# Processing Record 8 of Set 16 | chancay
# Processing Record 9 of Set 16 | belgrade
# Processing Record 10 of Set 16 | kyzyl-suu
# Processing Record 11 of Set 16 | najran
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Busselton -33.65  115.33     46.00        76          94        2.08
# 1        Tilichiki  60.47  166.10     45.88        93         100        6.98
# 2        Kununurra -15.77  128.73     73.40        82          40        2.21
# 3        Tocopilla -22.09  -70.20     63.75        48           6       11.18
# 4  Bambous Virieux -20.34   57.76     72.00        73          75       12.75
# 5             Lata  40.16   -8.33     87.01        50           0       13.31
# 6        Hanstholm  57.12    8.62     73.99        67          71        8.50
# 7       Tymovskoye  50.85  142.66     48.51        92          20        2.28
# 8        Ilulissat  69.22  -51.10     53.60        37          40        4.70
# 9      Grand Gaube -20.01   57.66     72.00        65          32       10.00
#
#   Current Description Country                 Date
# 0     overcast clouds      AU  2020-08-19 16:18:40
# 1     overcast clouds      RU  2020-08-19 16:18:40
# 2    scattered clouds      AU  2020-08-19 16:18:40
# 3           clear sky      CL  2020-08-19 16:18:41
# 4         shower rain      MU  2020-08-19 16:18:41
# 5           clear sky      PT  2020-08-19 16:18:41
# 6       broken clouds      DK  2020-08-19 16:18:41
# 7          few clouds      RU  2020-08-19 16:18:42
# 8    scattered clouds      GL  2020-08-19 16:18:42
# 9    scattered clouds      MU  2020-08-19 16:18:42

# %%
# Organize the  columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton      AU -33.65  115.33     46.00        76          94
# 1        Tilichiki      RU  60.47  166.10     45.88        93         100
# 2        Kununurra      AU -15.77  128.73     73.40        82          40
# 3        Tocopilla      CL -22.09  -70.20     63.75        48           6
# 4  Bambous Virieux      MU -20.34   57.76     72.00        73          75
# 5             Lata      PT  40.16   -8.33     87.01        50           0
# 6        Hanstholm      DK  57.12    8.62     73.99        67          71
# 7       Tymovskoye      RU  50.85  142.66     48.51        92          20
# 8        Ilulissat      GL  69.22  -51.10     53.60        37          40
# 9      Grand Gaube      MU -20.01   57.66     72.00        65          32
#
#    Wind Speed Current Description
# 0        2.08     overcast clouds
# 1        6.98     overcast clouds
# 2        2.21    scattered clouds
# 3       11.18           clear sky
# 4       12.75         shower rain
# 5       13.31           clear sky
# 6        8.50       broken clouds
# 7        2.28          few clouds
# 8        4.70    scattered clouds
# 9       10.00    scattered clouds

# %%
# Create and export the final Data Frame into a CSV
city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
