# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Zipping the pairs in a tuple with zip() function.
lat_lngs = zip(lats, lngs)

# %%
#Unpack zip tuples into a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination using citypy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then append to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count.
len(cities)
# Out:
# 737

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isangel
# Processing Record 2 of Set 1 | rehoboth
# Processing Record 3 of Set 1 | gouyave
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 1 | sorland
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | saint-augustin
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | katsuura
# Processing Record 23 of Set 1 | amahai
# Processing Record 24 of Set 1 | saint-georges
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | grand gaube
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | ilulissat
# Processing Record 31 of Set 1 | maloy
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | redondela
# Processing Record 39 of Set 1 | saravena
# Processing Record 40 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | manama
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | celestun
# Processing Record 45 of Set 1 | yulara
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | mount gambier
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | landsberg
# Processing Record 1 of Set 2 | iqaluit
# Processing Record 2 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 2 | atambua
# Processing Record 4 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 2 | salalah
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | makakilo city
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | bathsheba
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | shimoda
# Processing Record 14 of Set 2 | newport
# Processing Record 15 of Set 2 | chioggia
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | kharan
# Processing Record 18 of Set 2 | ancud
# Processing Record 19 of Set 2 | carutapera
# Processing Record 20 of Set 2 | cherskiy
# Processing Record 21 of Set 2 | yongan
# Processing Record 22 of Set 2 | guerrero negro
# Processing Record 23 of Set 2 | tazovskiy
# Processing Record 24 of Set 2 | parczew
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | kandrian
# Processing Record 27 of Set 2 | norman wells
# Processing Record 28 of Set 2 | nador
# Processing Record 29 of Set 2 | constitucion
# Processing Record 30 of Set 2 | port lincoln
# Processing Record 31 of Set 2 | carauari
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | tasiilaq
# Processing Record 36 of Set 2 | east wenatchee bench
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | coquimbo
# Processing Record 40 of Set 2 | bolshaya rechka
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | semey
# Processing Record 43 of Set 2 | henties bay
# Processing Record 44 of Set 2 | olafsvik
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | rawlins
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | weleri
# Processing Record 49 of Set 2 | thinadhoo
# Processing Record 50 of Set 2 | linhares
# Processing Record 1 of Set 3 | balimo
# City not found. Skipping...
# Processing Record 2 of Set 3 | cartagena del chaira
# Processing Record 3 of Set 3 | srednekolymsk
# Processing Record 4 of Set 3 | finschhafen
# Processing Record 5 of Set 3 | port hardy
# Processing Record 6 of Set 3 | sitka
# Processing Record 7 of Set 3 | mikuni
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | geraldton
# Processing Record 12 of Set 3 | arti
# Processing Record 13 of Set 3 | namibe
# Processing Record 14 of Set 3 | robertsport
# Processing Record 15 of Set 3 | markova
# Processing Record 16 of Set 3 | yar-sale
# Processing Record 17 of Set 3 | esperance
# Processing Record 18 of Set 3 | kudahuvadhoo
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | tawang
# Processing Record 21 of Set 3 | vallenar
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | turmero
# Processing Record 26 of Set 3 | kalaiya
# Processing Record 27 of Set 3 | palmer
# Processing Record 28 of Set 3 | antofagasta
# Processing Record 29 of Set 3 | tezu
# Processing Record 30 of Set 3 | ixtapa
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | oeiras do para
# Processing Record 33 of Set 3 | komsomolskiy
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 3 | gamba
# Processing Record 39 of Set 3 | talnakh
# Processing Record 40 of Set 3 | gurupi
# Processing Record 41 of Set 3 | broome
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | pacific grove
# Processing Record 44 of Set 3 | yelniki
# Processing Record 45 of Set 3 | douazeci si trei august
# Processing Record 46 of Set 3 | partapur
# Processing Record 47 of Set 3 | plettenberg bay
# Processing Record 48 of Set 3 | cornelius
# Processing Record 49 of Set 3 | khetri
# Processing Record 50 of Set 3 | tupiza
# Processing Record 1 of Set 4 | belomorsk
# Processing Record 2 of Set 4 | vanimo
# Processing Record 3 of Set 4 | valparaiso
# Processing Record 4 of Set 4 | keffi
# Processing Record 5 of Set 4 | progreso
# Processing Record 6 of Set 4 | kunya
# Processing Record 7 of Set 4 | leningradskiy
# Processing Record 8 of Set 4 | pittsburg
# Processing Record 9 of Set 4 | xining
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | berlevag
# Processing Record 12 of Set 4 | bom despacho
# Processing Record 13 of Set 4 | caravelas
# Processing Record 14 of Set 4 | erzin
# Processing Record 15 of Set 4 | la palma
# Processing Record 16 of Set 4 | conde
# Processing Record 17 of Set 4 | caborca
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | mitsamiouli
# Processing Record 20 of Set 4 | malindi
# Processing Record 21 of Set 4 | san quintin
# Processing Record 22 of Set 4 | jawhar
# Processing Record 23 of Set 4 | dali
# Processing Record 24 of Set 4 | nyurba
# Processing Record 25 of Set 4 | fort nelson
# Processing Record 26 of Set 4 | upata
# Processing Record 27 of Set 4 | nikolskoye
# Processing Record 28 of Set 4 | flin flon
# Processing Record 29 of Set 4 | imbituba
# Processing Record 30 of Set 4 | hailar
# Processing Record 31 of Set 4 | krasnoselkup
# Processing Record 32 of Set 4 | bozdar
# Processing Record 33 of Set 4 | ola
# Processing Record 34 of Set 4 | kruisfontein
# Processing Record 35 of Set 4 | kuusamo
# Processing Record 36 of Set 4 | luderitz
# Processing Record 37 of Set 4 | cayenne
# Processing Record 38 of Set 4 | paamiut
# Processing Record 39 of Set 4 | tuatapere
# Processing Record 40 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 4 | wamba
# Processing Record 42 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 4 | saint-pierre
# Processing Record 44 of Set 4 | deputatskiy
# Processing Record 45 of Set 4 | ponta do sol
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | sao miguel do araguaia
# Processing Record 48 of Set 4 | kutum
# Processing Record 49 of Set 4 | oussouye
# Processing Record 50 of Set 4 | kedrovyy
# Processing Record 1 of Set 5 | fomboni
# Processing Record 2 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 5 | sorong
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | laguna
# Processing Record 6 of Set 5 | lavrentiya
# Processing Record 7 of Set 5 | severnyy
# Processing Record 8 of Set 5 | andenes
# Processing Record 9 of Set 5 | lorengau
# Processing Record 10 of Set 5 | teya
# Processing Record 11 of Set 5 | bokhan
# Processing Record 12 of Set 5 | moron
# Processing Record 13 of Set 5 | poum
# Processing Record 14 of Set 5 | fortuna
# Processing Record 15 of Set 5 | voh
# Processing Record 16 of Set 5 | ahipara
# Processing Record 17 of Set 5 | ulladulla
# Processing Record 18 of Set 5 | hami
# Processing Record 19 of Set 5 | labuhan
# Processing Record 20 of Set 5 | santa rosa
# Processing Record 21 of Set 5 | adrar
# Processing Record 22 of Set 5 | general roca
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | goleniow
# Processing Record 25 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 26 of Set 5 | peleduy
# Processing Record 27 of Set 5 | nemuro
# Processing Record 28 of Set 5 | rancho palos verdes
# Processing Record 29 of Set 5 | bulgan
# Processing Record 30 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 5 | doume
# Processing Record 32 of Set 5 | whyalla
# Processing Record 33 of Set 5 | uige
# Processing Record 34 of Set 5 | sur
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | clyde river
# Processing Record 37 of Set 5 | porto novo
# Processing Record 38 of Set 5 | narodychi
# Processing Record 39 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 5 | orotukan
# Processing Record 41 of Set 5 | vestmannaeyjar
# Processing Record 42 of Set 5 | mantua
# Processing Record 43 of Set 5 | long branch
# Processing Record 44 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 5 | mahebourg
# Processing Record 46 of Set 5 | payo
# Processing Record 47 of Set 5 | dingle
# Processing Record 48 of Set 5 | pedasi
# Processing Record 49 of Set 5 | gualeguay
# Processing Record 50 of Set 5 | vostochnyy
# Processing Record 1 of Set 6 | parras
# City not found. Skipping...
# Processing Record 2 of Set 6 | byron bay
# Processing Record 3 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 6 | neos marmaras
# Processing Record 5 of Set 6 | iralaya
# Processing Record 6 of Set 6 | noyabrsk
# Processing Record 7 of Set 6 | zongozotla
# Processing Record 8 of Set 6 | the valley
# Processing Record 9 of Set 6 | abu samrah
# Processing Record 10 of Set 6 | grande prairie
# Processing Record 11 of Set 6 | niteroi
# Processing Record 12 of Set 6 | namatanai
# Processing Record 13 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 6 | bandarbeyla
# Processing Record 15 of Set 6 | kodiak
# Processing Record 16 of Set 6 | ostrovnoy
# Processing Record 17 of Set 6 | marsh harbour
# Processing Record 18 of Set 6 | khovu-aksy
# Processing Record 19 of Set 6 | narrabri
# Processing Record 20 of Set 6 | kahului
# Processing Record 21 of Set 6 | ust-kuyga
# Processing Record 22 of Set 6 | havoysund
# Processing Record 23 of Set 6 | saint-joseph
# Processing Record 24 of Set 6 | pisco
# Processing Record 25 of Set 6 | tura
# Processing Record 26 of Set 6 | ribeira grande
# Processing Record 27 of Set 6 | sao domingos do maranhao
# Processing Record 28 of Set 6 | chambas
# Processing Record 29 of Set 6 | harper
# Processing Record 30 of Set 6 | san patricio
# Processing Record 31 of Set 6 | castro
# Processing Record 32 of Set 6 | chapais
# Processing Record 33 of Set 6 | alugan
# Processing Record 34 of Set 6 | nizhnevartovsk
# Processing Record 35 of Set 6 | los negros
# Processing Record 36 of Set 6 | cockburn town
# Processing Record 37 of Set 6 | maningrida
# Processing Record 38 of Set 6 | saint-denis
# Processing Record 39 of Set 6 | shelburne
# Processing Record 40 of Set 6 | iwanai
# Processing Record 41 of Set 6 | camacha
# Processing Record 42 of Set 6 | la vergne
# Processing Record 43 of Set 6 | kavieng
# Processing Record 44 of Set 6 | lodeynoye pole
# Processing Record 45 of Set 6 | sabha
# Processing Record 46 of Set 6 | porto san giorgio
# Processing Record 47 of Set 6 | sistranda
# Processing Record 48 of Set 6 | pokhara
# Processing Record 49 of Set 6 | reconquista
# Processing Record 50 of Set 6 | armizonskoye
# Processing Record 1 of Set 7 | buchanan
# Processing Record 2 of Set 7 | rocha
# Processing Record 3 of Set 7 | matagami
# Processing Record 4 of Set 7 | butaritari
# Processing Record 5 of Set 7 | champawat
# Processing Record 6 of Set 7 | sosua
# Processing Record 7 of Set 7 | gat
# Processing Record 8 of Set 7 | kultuk
# Processing Record 9 of Set 7 | port keats
# Processing Record 10 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 7 | zhigansk
# Processing Record 12 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 7 | cidreira
# Processing Record 14 of Set 7 | kusu
# Processing Record 15 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 7 | qazvin
# Processing Record 17 of Set 7 | tilichiki
# Processing Record 18 of Set 7 | abomsa
# Processing Record 19 of Set 7 | bengkulu
# Processing Record 20 of Set 7 | malangali
# Processing Record 21 of Set 7 | betong
# Processing Record 22 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 7 | zeya
# Processing Record 24 of Set 7 | asau
# Processing Record 25 of Set 7 | sananduva
# Processing Record 26 of Set 7 | vuktyl
# Processing Record 27 of Set 7 | camana
# Processing Record 28 of Set 7 | riyadh
# Processing Record 29 of Set 7 | kathu
# Processing Record 30 of Set 7 | lata
# Processing Record 31 of Set 7 | brzesko
# Processing Record 32 of Set 7 | portland
# Processing Record 33 of Set 7 | airai
# Processing Record 34 of Set 7 | obzor
# Processing Record 35 of Set 7 | kattivakkam
# Processing Record 36 of Set 7 | yantai
# Processing Record 37 of Set 7 | touros
# Processing Record 38 of Set 7 | mamallapuram
# Processing Record 39 of Set 7 | ulaangom
# Processing Record 40 of Set 7 | parabel
# Processing Record 41 of Set 7 | codrington
# Processing Record 42 of Set 7 | westport
# Processing Record 43 of Set 7 | brandon
# Processing Record 44 of Set 7 | vila velha
# Processing Record 45 of Set 7 | ushirombo
# Processing Record 46 of Set 7 | longyearbyen
# Processing Record 47 of Set 7 | alta floresta
# Processing Record 48 of Set 7 | bilma
# Processing Record 49 of Set 7 | san vicente
# Processing Record 50 of Set 7 | lagoa
# Processing Record 1 of Set 8 | champerico
# Processing Record 2 of Set 8 | shahreza
# Processing Record 3 of Set 8 | novaya ladoga
# Processing Record 4 of Set 8 | hervey bay
# Processing Record 5 of Set 8 | songjianghe
# Processing Record 6 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 8 | kupang
# Processing Record 8 of Set 8 | hamilton
# Processing Record 9 of Set 8 | corsicana
# Processing Record 10 of Set 8 | abreus
# Processing Record 11 of Set 8 | juneau
# Processing Record 12 of Set 8 | santa maria
# Processing Record 13 of Set 8 | oranjemund
# Processing Record 14 of Set 8 | dabra
# Processing Record 15 of Set 8 | port-cartier
# Processing Record 16 of Set 8 | fairbanks
# Processing Record 17 of Set 8 | simao
# Processing Record 18 of Set 8 | kayasula
# Processing Record 19 of Set 8 | kade
# Processing Record 20 of Set 8 | fruitvale
# Processing Record 21 of Set 8 | mercedes
# Processing Record 22 of Set 8 | bagasara
# City not found. Skipping...
# Processing Record 23 of Set 8 | neuquen
# Processing Record 24 of Set 8 | ambon
# Processing Record 25 of Set 8 | panzhihua
# Processing Record 26 of Set 8 | inhambane
# Processing Record 27 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 29 of Set 8 | broken hill
# Processing Record 30 of Set 8 | nome
# Processing Record 31 of Set 8 | medicine hat
# Processing Record 32 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 8 | narsaq
# Processing Record 34 of Set 8 | safaga
# Processing Record 35 of Set 8 | milkovo
# Processing Record 36 of Set 8 | kaputa
# Processing Record 37 of Set 8 | paita
# Processing Record 38 of Set 8 | jining
# Processing Record 39 of Set 8 | kapoeta
# Processing Record 40 of Set 8 | kemijarvi
# Processing Record 41 of Set 8 | ampanihy
# Processing Record 42 of Set 8 | bar harbor
# Processing Record 43 of Set 8 | upington
# Processing Record 44 of Set 8 | vao
# Processing Record 45 of Set 8 | new albany
# Processing Record 46 of Set 8 | dukat
# Processing Record 47 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 49 of Set 8 | carmiano
# Processing Record 50 of Set 8 | haines junction
# Processing Record 1 of Set 9 | bethanien
# Processing Record 2 of Set 9 | avera
# Processing Record 3 of Set 9 | souillac
# Processing Record 4 of Set 9 | bambous virieux
# Processing Record 5 of Set 9 | biak
# Processing Record 6 of Set 9 | ylivieska
# Processing Record 7 of Set 9 | essenbach
# Processing Record 8 of Set 9 | moose factory
# Processing Record 9 of Set 9 | buala
# Processing Record 10 of Set 9 | tautira
# Processing Record 11 of Set 9 | husavik
# Processing Record 12 of Set 9 | front royal
# Processing Record 13 of Set 9 | mehamn
# Processing Record 14 of Set 9 | tessalit
# Processing Record 15 of Set 9 | necochea
# Processing Record 16 of Set 9 | raudeberg
# Processing Record 17 of Set 9 | faya
# Processing Record 18 of Set 9 | sioux lookout
# Processing Record 19 of Set 9 | boyolangu
# Processing Record 20 of Set 9 | okhotsk
# Processing Record 21 of Set 9 | altamira
# Processing Record 22 of Set 9 | wenling
# Processing Record 23 of Set 9 | cap malheureux
# Processing Record 24 of Set 9 | saijo
# Processing Record 25 of Set 9 | lukiv
# Processing Record 26 of Set 9 | shubarkuduk
# Processing Record 27 of Set 9 | arlit
# Processing Record 28 of Set 9 | ucluelet
# Processing Record 29 of Set 9 | margate
# Processing Record 30 of Set 9 | fort-de-france
# Processing Record 31 of Set 9 | manaus
# Processing Record 32 of Set 9 | zaysan
# Processing Record 33 of Set 9 | udachnyy
# Processing Record 34 of Set 9 | kaspiyskiy
# Processing Record 35 of Set 9 | debre tabor
# Processing Record 36 of Set 9 | okato
# Processing Record 37 of Set 9 | awjilah
# Processing Record 38 of Set 9 | mogadishu
# Processing Record 39 of Set 9 | omboue
# Processing Record 40 of Set 9 | formosa do rio preto
# Processing Record 41 of Set 9 | puerto escondido
# Processing Record 42 of Set 9 | dalby
# Processing Record 43 of Set 9 | kargil
# Processing Record 44 of Set 9 | beringovskiy
# Processing Record 45 of Set 9 | petrozavodsk
# Processing Record 46 of Set 9 | cheremnoye
# Processing Record 47 of Set 9 | aklavik
# Processing Record 48 of Set 9 | san andres
# Processing Record 49 of Set 9 | kaka
# Processing Record 50 of Set 9 | ust-omchug
# Processing Record 1 of Set 10 | riachao das neves
# Processing Record 2 of Set 10 | lufilufi
# Processing Record 3 of Set 10 | samarai
# Processing Record 4 of Set 10 | tevaitoa
# Processing Record 5 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 10 | curuguaty
# Processing Record 7 of Set 10 | ewa beach
# Processing Record 8 of Set 10 | kavaratti
# Processing Record 9 of Set 10 | norsup
# Processing Record 10 of Set 10 | alyangula
# Processing Record 11 of Set 10 | dalbandin
# Processing Record 12 of Set 10 | vasto
# Processing Record 13 of Set 10 | luanda
# Processing Record 14 of Set 10 | lulea
# Processing Record 15 of Set 10 | toamasina
# Processing Record 16 of Set 10 | gayny
# Processing Record 17 of Set 10 | anadyr
# Processing Record 18 of Set 10 | richards bay
# Processing Record 19 of Set 10 | pangai
# Processing Record 20 of Set 10 | kidal
# Processing Record 21 of Set 10 | taoudenni
# Processing Record 22 of Set 10 | slobidka
# Processing Record 23 of Set 10 | yumen
# Processing Record 24 of Set 10 | sao filipe
# Processing Record 25 of Set 10 | shakawe
# Processing Record 26 of Set 10 | rawson
# Processing Record 27 of Set 10 | po
# City not found. Skipping...
# Processing Record 28 of Set 10 | afua
# Processing Record 29 of Set 10 | faanui
# Processing Record 30 of Set 10 | mayo
# Processing Record 31 of Set 10 | hadishahr
# Processing Record 32 of Set 10 | warwick
# Processing Record 33 of Set 10 | bay roberts
# Processing Record 34 of Set 10 | hofn
# Processing Record 35 of Set 10 | araguatins
# City not found. Skipping...
# Processing Record 36 of Set 10 | kaabong
# Processing Record 37 of Set 10 | ust-tsilma
# Processing Record 38 of Set 10 | yamada
# Processing Record 39 of Set 10 | lompoc
# Processing Record 40 of Set 10 | channel-port aux basques
# Processing Record 41 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 42 of Set 10 | nishihara
# Processing Record 43 of Set 10 | gao
# Processing Record 44 of Set 10 | kinablangan
# Processing Record 45 of Set 10 | khani
# Processing Record 46 of Set 10 | naze
# Processing Record 47 of Set 10 | lima
# Processing Record 48 of Set 10 | marsabit
# Processing Record 49 of Set 10 | eforie
# City not found. Skipping...
# Processing Record 50 of Set 10 | arman
# Processing Record 1 of Set 11 | gull lake
# Processing Record 2 of Set 11 | bakel
# Processing Record 3 of Set 11 | bonham
# Processing Record 4 of Set 11 | methoni
# Processing Record 5 of Set 11 | kulhudhuffushi
# Processing Record 6 of Set 11 | wagar
# Processing Record 7 of Set 11 | hasaki
# Processing Record 8 of Set 11 | atherton
# Processing Record 9 of Set 11 | kenai
# Processing Record 10 of Set 11 | oriximina
# Processing Record 11 of Set 11 | guru har sahai
# Processing Record 12 of Set 11 | ushtobe
# Processing Record 13 of Set 11 | la fria
# Processing Record 14 of Set 11 | bowen
# Processing Record 15 of Set 11 | kabanjahe
# Processing Record 16 of Set 11 | isiolo
# Processing Record 17 of Set 11 | igarka
# Processing Record 18 of Set 11 | chillicothe
# Processing Record 19 of Set 11 | najran
# Processing Record 20 of Set 11 | lubango
# Processing Record 21 of Set 11 | alghero
# Processing Record 22 of Set 11 | shache
# Processing Record 23 of Set 11 | etaples
# Processing Record 24 of Set 11 | kuytun
# Processing Record 25 of Set 11 | muravlenko
# Processing Record 26 of Set 11 | taltal
# Processing Record 27 of Set 11 | whitehorse
# Processing Record 28 of Set 11 | okha
# Processing Record 29 of Set 11 | chase
# Processing Record 30 of Set 11 | quesnel
# Processing Record 31 of Set 11 | kijang
# Processing Record 32 of Set 11 | luxor
# Processing Record 33 of Set 11 | altay
# Processing Record 34 of Set 11 | marrakesh
# Processing Record 35 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 11 | willowmore
# Processing Record 37 of Set 11 | waipawa
# Processing Record 38 of Set 11 | chimore
# Processing Record 39 of Set 11 | wanaka
# Processing Record 40 of Set 11 | omsukchan
# Processing Record 41 of Set 11 | turukhansk
# Processing Record 42 of Set 11 | linjiang
# Processing Record 43 of Set 11 | los llanos de aridane
# Processing Record 44 of Set 11 | hovd
# Processing Record 45 of Set 11 | mbanza-ngungu
# Processing Record 46 of Set 11 | listvyanka
# Processing Record 47 of Set 11 | careiro da varzea
# Processing Record 48 of Set 11 | sechura
# Processing Record 49 of Set 11 | kilindoni
# Processing Record 50 of Set 11 | assentoft
# Processing Record 1 of Set 12 | gazanjyk
# Processing Record 2 of Set 12 | takoradi
# Processing Record 3 of Set 12 | burnie
# Processing Record 4 of Set 12 | lazaro cardenas
# Processing Record 5 of Set 12 | plastun
# Processing Record 6 of Set 12 | vizinga
# Processing Record 7 of Set 12 | bratsk
# Processing Record 8 of Set 12 | puerto colombia
# Processing Record 9 of Set 12 | manokwari
# Processing Record 10 of Set 12 | marzuq
# Processing Record 11 of Set 12 | porto
# Processing Record 12 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 13 of Set 12 | pontes e lacerda
# Processing Record 14 of Set 12 | brae
# Processing Record 15 of Set 12 | birao
# Processing Record 16 of Set 12 | casablanca
# Processing Record 17 of Set 12 | teguldet
# Processing Record 18 of Set 12 | mindelo
# Processing Record 19 of Set 12 | belo oriente
# Processing Record 20 of Set 12 | derzhavinsk
# Processing Record 21 of Set 12 | sinnamary
# Processing Record 22 of Set 12 | ingham
# Processing Record 23 of Set 12 | chalinze
# Processing Record 24 of Set 12 | langres
# Processing Record 25 of Set 12 | mitu
# Processing Record 26 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 12 | beloha
# Processing Record 28 of Set 12 | san cristobal
# Processing Record 29 of Set 12 | kendari
# Processing Record 30 of Set 12 | gushikawa
# Processing Record 31 of Set 12 | matara
# Processing Record 32 of Set 12 | zhuhai
# Processing Record 33 of Set 12 | adiake
# Processing Record 34 of Set 12 | kununurra
# Processing Record 35 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 12 | porto uniao
# Processing Record 37 of Set 12 | gizo
# Processing Record 38 of Set 12 | batouri
# Processing Record 39 of Set 12 | santa lucia
# Processing Record 40 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 12 | banda aceh
# Processing Record 42 of Set 12 | hidalgotitlan
# Processing Record 43 of Set 12 | taksimo
# Processing Record 44 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 45 of Set 12 | port hueneme
# Processing Record 46 of Set 12 | cabra
# Processing Record 47 of Set 12 | lakes entrance
# Processing Record 48 of Set 12 | niquero
# Processing Record 49 of Set 12 | yerbogachen
# Processing Record 50 of Set 12 | albenga
# Processing Record 1 of Set 13 | guanica
# Processing Record 2 of Set 13 | namie
# Processing Record 3 of Set 13 | amposta
# Processing Record 4 of Set 13 | comodoro rivadavia
# Processing Record 5 of Set 13 | bose
# Processing Record 6 of Set 13 | catia la mar
# Processing Record 7 of Set 13 | roma
# Processing Record 8 of Set 13 | sola
# Processing Record 9 of Set 13 | yabluniv
# Processing Record 10 of Set 13 | nakasongola
# Processing Record 11 of Set 13 | linguere
# Processing Record 12 of Set 13 | berdyuzhye
# City not found. Skipping...
# Processing Record 13 of Set 13 | atar
# Processing Record 14 of Set 13 | gamboma
# Processing Record 15 of Set 13 | okahandja
# Processing Record 16 of Set 13 | xuddur
# Processing Record 17 of Set 13 | half moon bay
# Processing Record 18 of Set 13 | orel-izumrud
# Processing Record 19 of Set 13 | chitral
# Processing Record 20 of Set 13 | sukhodol
# Processing Record 21 of Set 13 | sibu
# Processing Record 22 of Set 13 | huntsville
# Processing Record 23 of Set 13 | sisimiut
# Processing Record 24 of Set 13 | san pedro
# Processing Record 25 of Set 13 | cruzeiro do sul
# Processing Record 26 of Set 13 | isugod
# Processing Record 27 of Set 13 | san jeronimo
# Processing Record 28 of Set 13 | ocos
# Processing Record 29 of Set 13 | vila franca do campo
# Processing Record 30 of Set 13 | peniche
# Processing Record 31 of Set 13 | rongcheng
# Processing Record 32 of Set 13 | rochegda
# Processing Record 33 of Set 13 | malinyi
# Processing Record 34 of Set 13 | kushmurun
# Processing Record 35 of Set 13 | preobrazheniye
# Processing Record 36 of Set 13 | zheleznogorsk
# Processing Record 37 of Set 13 | saldanha
# Processing Record 38 of Set 13 | eyl
# Processing Record 39 of Set 13 | phangnga
# Processing Record 40 of Set 13 | robat karim
# Processing Record 41 of Set 13 | dzhebariki-khaya
# Processing Record 42 of Set 13 | college
# Processing Record 43 of Set 13 | guiratinga
# Processing Record 44 of Set 13 | port hedland
# Processing Record 45 of Set 13 | tazmalt
# Processing Record 46 of Set 13 | alofi
# Processing Record 47 of Set 13 | same
# Processing Record 48 of Set 13 | boxmeer
# Processing Record 49 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 50 of Set 13 | san policarpo
# Processing Record 1 of Set 14 | jaisalmer
# Processing Record 2 of Set 14 | isla mujeres
# Processing Record 3 of Set 14 | manzanillo
# Processing Record 4 of Set 14 | oktyabrskiy
# Processing Record 5 of Set 14 | berdigestyakh
# Processing Record 6 of Set 14 | pangnirtung
# Processing Record 7 of Set 14 | kantabanji
# Processing Record 8 of Set 14 | vaitape
# Processing Record 9 of Set 14 | bereda
# Processing Record 10 of Set 14 | zabid
# Processing Record 11 of Set 14 | atlantic city
# Processing Record 12 of Set 14 | waspan
# Processing Record 13 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 14 | barcelos
# Processing Record 15 of Set 14 | delta del tigre
# Processing Record 16 of Set 14 | lianzhou
# Processing Record 17 of Set 14 | ginda
# Processing Record 18 of Set 14 | bendigo
# Processing Record 19 of Set 14 | vilhena
# Processing Record 20 of Set 14 | shieli
# Processing Record 21 of Set 14 | la ronge
# Processing Record 22 of Set 14 | cantanhede
# Processing Record 23 of Set 14 | boguchany
# Processing Record 24 of Set 14 | wabag
# Processing Record 25 of Set 14 | ondjiva
# Processing Record 26 of Set 14 | goderich
# Processing Record 27 of Set 14 | cesis
# Processing Record 28 of Set 14 | tepechitlan
# Processing Record 29 of Set 14 | dumai
# Processing Record 30 of Set 14 | hobyo
# Processing Record 31 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 32 of Set 14 | tsabong
# Processing Record 33 of Set 14 | shirokiy
# Processing Record 34 of Set 14 | meulaboh
# Processing Record 35 of Set 14 | hit
# Processing Record 36 of Set 14 | saint-francois
# Processing Record 37 of Set 14 | abu dhabi
# Processing Record 38 of Set 14 | edgewater
# Processing Record 39 of Set 14 | nizhniy kuranakh
# Processing Record 40 of Set 14 | north bend
# Processing Record 41 of Set 14 | dunedin
# Processing Record 42 of Set 14 | illapel
# Processing Record 43 of Set 14 | marsa matruh
# Processing Record 44 of Set 14 | ardabil
# Processing Record 45 of Set 14 | wampusirpi
# City not found. Skipping...
# Processing Record 46 of Set 14 | mao
# Processing Record 47 of Set 14 | sibolga
# Processing Record 48 of Set 14 | baruun-urt
# Processing Record 49 of Set 14 | perth
# Processing Record 50 of Set 14 | zheleznodorozhnyy
# Processing Record 1 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 15 | mmabatho
# Processing Record 4 of Set 15 | mafinga
# Processing Record 5 of Set 15 | riwaka
# Processing Record 6 of Set 15 | sao gabriel da cachoeira
# Processing Record 7 of Set 15 | san juan del sur
# Processing Record 8 of Set 15 | crotone
# Processing Record 9 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 15 | aakirkeby
# City not found. Skipping...
# Processing Record 12 of Set 15 | kirov
# Processing Record 13 of Set 15 | kristiinankaupunki
# Processing Record 14 of Set 15 | abonnema
# Processing Record 15 of Set 15 | verkhnevilyuysk
# Processing Record 16 of Set 15 | skjaerhollen
# City not found. Skipping...
# Processing Record 17 of Set 15 | moura
# Processing Record 18 of Set 15 | dvinskoy
# Processing Record 19 of Set 15 | sao joao da barra
# Processing Record 20 of Set 15 | lincoln
# Processing Record 21 of Set 15 | briancon
# Processing Record 22 of Set 15 | urusha
# Processing Record 23 of Set 15 | bitung
# Processing Record 24 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 15 | uchiza
# Processing Record 26 of Set 15 | rafaela
# Processing Record 27 of Set 15 | olinda
# Processing Record 28 of Set 15 | dabakala
# Processing Record 29 of Set 15 | sobolevo
# Processing Record 30 of Set 15 | tigil
# Processing Record 31 of Set 15 | mbandaka
# Processing Record 32 of Set 15 | las vigas
# Processing Record 33 of Set 15 | novikovo
# Processing Record 34 of Set 15 | san cosme y damian
# Processing Record 35 of Set 15 | baijiantan
# Processing Record 36 of Set 15 | praia
# Processing Record 37 of Set 15 | smithers
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 679

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Isangel -19.55  169.27     71.46        68           2        3.76
# 1     Rehoboth -23.32   17.08     35.74        62           0        5.50
# 2      Gouyave  12.16  -61.73     87.80        70          75       20.80
# 3        Bluff -46.60  168.33     42.01        97          93        5.41
# 4      Rikitea -23.12 -134.97     70.90        85         100       15.48
# 5      Ushuaia -54.80  -68.30     42.80        75          75       28.86
# 6      Qaanaaq  77.48  -69.36     45.01        88         100        3.42
# 7      Sorland  67.67   12.69     48.20        87          40        5.82
# 8  Provideniya  64.38 -173.30     53.60        81         100        2.24
# 9       Hobart -42.88  147.33     46.00        87          75        5.82
#
#   Current Description Country                 Date
# 0           clear sky      VU  2020-08-19 20:40:20
# 1           clear sky      NA  2020-08-19 20:40:20
# 2       broken clouds      GD  2020-08-19 20:40:20
# 3     overcast clouds      NZ  2020-08-19 20:40:21
# 4     overcast clouds      PF  2020-08-19 20:40:21
# 5         shower rain      AR  2020-08-19 20:38:42
# 6       moderate rain      GL  2020-08-19 20:40:21
# 7    scattered clouds      NO  2020-08-19 20:40:22
# 8     overcast clouds      RU  2020-08-19 20:40:22
# 9       broken clouds      AU  2020-08-19 20:39:43

# %%
# Organize the columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Isangel      VU -19.55  169.27     71.46        68           2
# 1     Rehoboth      NA -23.32   17.08     35.74        62           0
# 2      Gouyave      GD  12.16  -61.73     87.80        70          75
# 3        Bluff      NZ -46.60  168.33     42.01        97          93
# 4      Rikitea      PF -23.12 -134.97     70.90        85         100
# 5      Ushuaia      AR -54.80  -68.30     42.80        75          75
# 6      Qaanaaq      GL  77.48  -69.36     45.01        88         100
# 7      Sorland      NO  67.67   12.69     48.20        87          40
# 8  Provideniya      RU  64.38 -173.30     53.60        81         100
# 9       Hobart      AU -42.88  147.33     46.00        87          75
#
#    Wind Speed Current Description
# 0        3.76           clear sky
# 1        5.50           clear sky
# 2       20.80       broken clouds
# 3        5.41     overcast clouds
# 4       15.48     overcast clouds
# 5       28.86         shower rain
# 6        3.42       moderate rain
# 7        5.82    scattered clouds
# 8        2.24     overcast clouds
# 9        5.82       broken clouds

# %%
# Create and export the final Data Frame into a CSV
city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
