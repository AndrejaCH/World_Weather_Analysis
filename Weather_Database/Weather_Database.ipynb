# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Zipping the pairs in a tuple with zip() function.
lat_lngs = zip(lats, lngs)

# %%
#Unpack zip tuples into a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination using citypy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then append to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count.
len(cities)
# Out:
# 735

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mareeba
# Processing Record 2 of Set 1 | bilibino
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | pangnirtung
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | mahibadhoo
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | coihaique
# Processing Record 12 of Set 1 | gat
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | moissala
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | taicheng
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | paso de carrasco
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | poum
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | rocha
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | saldanha
# Processing Record 31 of Set 1 | souillac
# Processing Record 32 of Set 1 | tura
# Processing Record 33 of Set 1 | tazovskiy
# Processing Record 34 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 35 of Set 1 | airai
# Processing Record 36 of Set 1 | bathsheba
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | sivaki
# Processing Record 39 of Set 1 | umea
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | kluang
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | bitung
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | norman wells
# Processing Record 1 of Set 2 | tignere
# Processing Record 2 of Set 2 | kitami
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | pisco
# Processing Record 5 of Set 2 | kargalinskaya
# Processing Record 6 of Set 2 | mao
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | camocim
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | virginia beach
# Processing Record 12 of Set 2 | margate
# Processing Record 13 of Set 2 | taoudenni
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | jalu
# Processing Record 16 of Set 2 | khandbari
# Processing Record 17 of Set 2 | bhuj
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | praia da vitoria
# Processing Record 20 of Set 2 | lichinga
# Processing Record 21 of Set 2 | ambon
# Processing Record 22 of Set 2 | bollnas
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | tocopilla
# Processing Record 25 of Set 2 | strezhevoy
# Processing Record 26 of Set 2 | kantunilkin
# Processing Record 27 of Set 2 | broome
# Processing Record 28 of Set 2 | aloleng
# Processing Record 29 of Set 2 | veraval
# Processing Record 30 of Set 2 | saint-martin-de-crau
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | naryan-mar
# Processing Record 33 of Set 2 | kalmunai
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 38 of Set 2 | bowen
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | summerville
# Processing Record 41 of Set 2 | hohhot
# Processing Record 42 of Set 2 | kirkenes
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | gornopravdinsk
# Processing Record 45 of Set 2 | san jeronimo
# Processing Record 46 of Set 2 | oum hadjer
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 2 | rikitea
# Processing Record 50 of Set 2 | canton
# Processing Record 1 of Set 3 | palmer
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | nikolskoye
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | casper
# Processing Record 6 of Set 3 | husavik
# Processing Record 7 of Set 3 | makakilo city
# Processing Record 8 of Set 3 | belyy yar
# Processing Record 9 of Set 3 | miles city
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | voh
# Processing Record 13 of Set 3 | clyde river
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | sinnamary
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | san ramon
# Processing Record 18 of Set 3 | mount pleasant
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | mahon
# Processing Record 21 of Set 3 | caravelas
# Processing Record 22 of Set 3 | pyshchug
# Processing Record 23 of Set 3 | rio gallegos
# Processing Record 24 of Set 3 | coquimbo
# Processing Record 25 of Set 3 | constitucion
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | sakakah
# Processing Record 28 of Set 3 | dingle
# Processing Record 29 of Set 3 | tocantinopolis
# City not found. Skipping...
# Processing Record 30 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 31 of Set 3 | maymyo
# Processing Record 32 of Set 3 | kindu
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | egvekinot
# Processing Record 35 of Set 3 | porto novo
# Processing Record 36 of Set 3 | osinki
# Processing Record 37 of Set 3 | hilo
# Processing Record 38 of Set 3 | itoman
# Processing Record 39 of Set 3 | tuatapere
# Processing Record 40 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 3 | barra do garcas
# Processing Record 42 of Set 3 | arrecife
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | kavieng
# Processing Record 45 of Set 3 | luocheng
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | kloulklubed
# Processing Record 48 of Set 3 | semey
# Processing Record 49 of Set 3 | college
# Processing Record 50 of Set 3 | schoneiche
# Processing Record 1 of Set 4 | kozhva
# Processing Record 2 of Set 4 | hawkesbury
# Processing Record 3 of Set 4 | nawada
# Processing Record 4 of Set 4 | bandar-e anzali
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 4 | pushchino
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | la seyne-sur-mer
# Processing Record 9 of Set 4 | guajara-mirim
# City not found. Skipping...
# Processing Record 10 of Set 4 | ylojarvi
# Processing Record 11 of Set 4 | aldan
# Processing Record 12 of Set 4 | jolo
# Processing Record 13 of Set 4 | vardo
# Processing Record 14 of Set 4 | la rioja
# Processing Record 15 of Set 4 | prince rupert
# Processing Record 16 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 4 | alice springs
# Processing Record 18 of Set 4 | kaeo
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | makiyivka
# Processing Record 21 of Set 4 | mount isa
# Processing Record 22 of Set 4 | rawson
# Processing Record 23 of Set 4 | fortuna
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | kosonsoy
# Processing Record 26 of Set 4 | basco
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | santa isabel
# Processing Record 29 of Set 4 | srednekolymsk
# Processing Record 30 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 4 | broken hill
# Processing Record 32 of Set 4 | half moon bay
# Processing Record 33 of Set 4 | muisne
# Processing Record 34 of Set 4 | castro
# Processing Record 35 of Set 4 | olafsvik
# Processing Record 36 of Set 4 | torbay
# Processing Record 37 of Set 4 | naze
# Processing Record 38 of Set 4 | toyooka
# Processing Record 39 of Set 4 | sao filipe
# Processing Record 40 of Set 4 | teguise
# Processing Record 41 of Set 4 | buala
# Processing Record 42 of Set 4 | sukhumi
# Processing Record 43 of Set 4 | waipawa
# Processing Record 44 of Set 4 | puerto madryn
# Processing Record 45 of Set 4 | calvinia
# Processing Record 46 of Set 4 | kulhudhuffushi
# Processing Record 47 of Set 4 | ostrovnoy
# Processing Record 48 of Set 4 | cape town
# Processing Record 49 of Set 4 | ballina
# Processing Record 50 of Set 4 | greymouth
# Processing Record 1 of Set 5 | nantucket
# Processing Record 2 of Set 5 | talnakh
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | pingliang
# Processing Record 5 of Set 5 | hami
# Processing Record 6 of Set 5 | cockburn town
# Processing Record 7 of Set 5 | grants
# Processing Record 8 of Set 5 | muroto
# Processing Record 9 of Set 5 | dwarka
# Processing Record 10 of Set 5 | tabou
# Processing Record 11 of Set 5 | urucara
# Processing Record 12 of Set 5 | santa vitoria do palmar
# Processing Record 13 of Set 5 | goderich
# Processing Record 14 of Set 5 | aldergrove
# Processing Record 15 of Set 5 | vanimo
# Processing Record 16 of Set 5 | puerto escondido
# Processing Record 17 of Set 5 | zhezkazgan
# Processing Record 18 of Set 5 | dikson
# Processing Record 19 of Set 5 | mariestad
# Processing Record 20 of Set 5 | butaritari
# Processing Record 21 of Set 5 | avarua
# Processing Record 22 of Set 5 | hambantota
# Processing Record 23 of Set 5 | south sioux city
# Processing Record 24 of Set 5 | los llanos de aridane
# Processing Record 25 of Set 5 | masuda
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | hobyo
# Processing Record 28 of Set 5 | mar del plata
# Processing Record 29 of Set 5 | teahupoo
# Processing Record 30 of Set 5 | port hardy
# Processing Record 31 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 5 | faya
# Processing Record 34 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 5 | tecoanapa
# Processing Record 36 of Set 5 | hofn
# Processing Record 37 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 5 | mandalgovi
# Processing Record 39 of Set 5 | meulaboh
# Processing Record 40 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 5 | dzaoudzi
# Processing Record 42 of Set 5 | codrington
# Processing Record 43 of Set 5 | tabas
# Processing Record 44 of Set 5 | yeppoon
# Processing Record 45 of Set 5 | shelekhov
# Processing Record 46 of Set 5 | nioki
# Processing Record 47 of Set 5 | lasa
# Processing Record 48 of Set 5 | anchorage
# Processing Record 49 of Set 5 | lorengau
# Processing Record 50 of Set 5 | port keats
# Processing Record 1 of Set 6 | touros
# Processing Record 2 of Set 6 | faanui
# Processing Record 3 of Set 6 | kenitra
# Processing Record 4 of Set 6 | mednogorsk
# Processing Record 5 of Set 6 | bambari
# Processing Record 6 of Set 6 | provideniya
# Processing Record 7 of Set 6 | shimoda
# Processing Record 8 of Set 6 | flinders
# Processing Record 9 of Set 6 | shirgaon
# Processing Record 10 of Set 6 | mbanza-ngungu
# Processing Record 11 of Set 6 | sola
# Processing Record 12 of Set 6 | carnarvon
# Processing Record 13 of Set 6 | kushiro
# Processing Record 14 of Set 6 | arcata
# Processing Record 15 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 16 of Set 6 | fort nelson
# Processing Record 17 of Set 6 | mabaruma
# Processing Record 18 of Set 6 | ketchikan
# Processing Record 19 of Set 6 | vire
# Processing Record 20 of Set 6 | beira
# Processing Record 21 of Set 6 | manadhoo
# Processing Record 22 of Set 6 | candolim
# Processing Record 23 of Set 6 | urumqi
# Processing Record 24 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 25 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 6 | shubarshi
# Processing Record 27 of Set 6 | peniche
# Processing Record 28 of Set 6 | aswan
# Processing Record 29 of Set 6 | beloha
# Processing Record 30 of Set 6 | sao joao da barra
# Processing Record 31 of Set 6 | darhan
# Processing Record 32 of Set 6 | gizo
# Processing Record 33 of Set 6 | diffa
# Processing Record 34 of Set 6 | chiang klang
# Processing Record 35 of Set 6 | vila
# Processing Record 36 of Set 6 | salym
# Processing Record 37 of Set 6 | iwanai
# Processing Record 38 of Set 6 | padang
# Processing Record 39 of Set 6 | upernavik
# Processing Record 40 of Set 6 | oistins
# Processing Record 41 of Set 6 | shumyachi
# Processing Record 42 of Set 6 | lovozero
# Processing Record 43 of Set 6 | kamenka
# Processing Record 44 of Set 6 | kahului
# Processing Record 45 of Set 6 | fez
# Processing Record 46 of Set 6 | coari
# Processing Record 47 of Set 6 | wanning
# Processing Record 48 of Set 6 | stara vyzhivka
# Processing Record 49 of Set 6 | mogadishu
# Processing Record 50 of Set 6 | carthage
# Processing Record 1 of Set 7 | pacific grove
# Processing Record 2 of Set 7 | ellensburg
# Processing Record 3 of Set 7 | mahebourg
# Processing Record 4 of Set 7 | rajshahi
# Processing Record 5 of Set 7 | santa cruz
# Processing Record 6 of Set 7 | tshikapa
# Processing Record 7 of Set 7 | antofagasta
# Processing Record 8 of Set 7 | mugur-aksy
# Processing Record 9 of Set 7 | ponta do sol
# Processing Record 10 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | namibe
# Processing Record 12 of Set 7 | katangli
# Processing Record 13 of Set 7 | la paz
# Processing Record 14 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 7 | la ronge
# Processing Record 17 of Set 7 | tamiahua
# Processing Record 18 of Set 7 | novoanninskiy
# Processing Record 19 of Set 7 | longyearbyen
# Processing Record 20 of Set 7 | mehran
# Processing Record 21 of Set 7 | isangel
# Processing Record 22 of Set 7 | lompoc
# Processing Record 23 of Set 7 | ahipara
# Processing Record 24 of Set 7 | port-gentil
# Processing Record 25 of Set 7 | lynchburg
# Processing Record 26 of Set 7 | bouna
# Processing Record 27 of Set 7 | worthington
# Processing Record 28 of Set 7 | gamboma
# Processing Record 29 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 7 | shingu
# Processing Record 31 of Set 7 | pascagoula
# Processing Record 32 of Set 7 | roald
# Processing Record 33 of Set 7 | solvychegodsk
# Processing Record 34 of Set 7 | hirara
# Processing Record 35 of Set 7 | korla
# Processing Record 36 of Set 7 | quatre cocos
# Processing Record 37 of Set 7 | taitung
# Processing Record 38 of Set 7 | puerto lempira
# Processing Record 39 of Set 7 | ruteng
# Processing Record 40 of Set 7 | xunchang
# Processing Record 41 of Set 7 | khani
# Processing Record 42 of Set 7 | eshowe
# Processing Record 43 of Set 7 | miraflores
# Processing Record 44 of Set 7 | saint-paul
# Processing Record 45 of Set 7 | angoram
# Processing Record 46 of Set 7 | mount gambier
# Processing Record 47 of Set 7 | tilichiki
# Processing Record 48 of Set 7 | olhao
# Processing Record 49 of Set 7 | ryomgard
# Processing Record 50 of Set 7 | vestmannaeyjar
# Processing Record 1 of Set 8 | san juan
# Processing Record 2 of Set 8 | kurchum
# Processing Record 3 of Set 8 | benjamin aceval
# Processing Record 4 of Set 8 | koboldo
# City not found. Skipping...
# Processing Record 5 of Set 8 | port macquarie
# Processing Record 6 of Set 8 | geraldton
# Processing Record 7 of Set 8 | axim
# Processing Record 8 of Set 8 | barma
# Processing Record 9 of Set 8 | saint-georges
# Processing Record 10 of Set 8 | gravelbourg
# Processing Record 11 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 8 | cumana
# Processing Record 13 of Set 8 | sungaipenuh
# Processing Record 14 of Set 8 | jutai
# Processing Record 15 of Set 8 | tuy hoa
# Processing Record 16 of Set 8 | gorkovskiy
# Processing Record 17 of Set 8 | kovur
# Processing Record 18 of Set 8 | westport
# Processing Record 19 of Set 8 | the pas
# Processing Record 20 of Set 8 | leningradskiy
# Processing Record 21 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 22 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 8 | vozuca
# Processing Record 24 of Set 8 | zapolyarnyy
# Processing Record 25 of Set 8 | tadine
# Processing Record 26 of Set 8 | loralai
# Processing Record 27 of Set 8 | nouadhibou
# Processing Record 28 of Set 8 | manaure
# Processing Record 29 of Set 8 | snezhnogorsk
# Processing Record 30 of Set 8 | aklavik
# Processing Record 31 of Set 8 | zhuhai
# Processing Record 32 of Set 8 | salekhard
# Processing Record 33 of Set 8 | yagodnoye
# Processing Record 34 of Set 8 | tongliao
# Processing Record 35 of Set 8 | mayor pablo lagerenza
# Processing Record 36 of Set 8 | akureyri
# Processing Record 37 of Set 8 | verkhnyaya inta
# Processing Record 38 of Set 8 | bartica
# Processing Record 39 of Set 8 | dedovichi
# Processing Record 40 of Set 8 | pakxan
# Processing Record 41 of Set 8 | ishigaki
# Processing Record 42 of Set 8 | manzhouli
# Processing Record 43 of Set 8 | jiangyou
# Processing Record 44 of Set 8 | ixtapa
# Processing Record 45 of Set 8 | belmonte
# Processing Record 46 of Set 8 | fairbanks
# Processing Record 47 of Set 8 | lower hutt
# Processing Record 48 of Set 8 | barguzin
# Processing Record 49 of Set 8 | tigre
# Processing Record 50 of Set 8 | mana
# Processing Record 1 of Set 9 | sidi bu zayd
# City not found. Skipping...
# Processing Record 2 of Set 9 | tupik
# Processing Record 3 of Set 9 | grand-lahou
# Processing Record 4 of Set 9 | los amates
# Processing Record 5 of Set 9 | baykit
# Processing Record 6 of Set 9 | guerrero negro
# Processing Record 7 of Set 9 | ponta delgada
# Processing Record 8 of Set 9 | umm kaddadah
# Processing Record 9 of Set 9 | angra
# City not found. Skipping...
# Processing Record 10 of Set 9 | riyadh
# Processing Record 11 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 12 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 9 | bengkulu
# Processing Record 14 of Set 9 | kutoarjo
# Processing Record 15 of Set 9 | plouzane
# Processing Record 16 of Set 9 | surgut
# Processing Record 17 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 9 | kaka
# Processing Record 19 of Set 9 | colesberg
# Processing Record 20 of Set 9 | kenai
# Processing Record 21 of Set 9 | mayo
# Processing Record 22 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 9 | hukuntsi
# Processing Record 24 of Set 9 | san vicente
# Processing Record 25 of Set 9 | kifri
# Processing Record 26 of Set 9 | simpang
# Processing Record 27 of Set 9 | beringovskiy
# Processing Record 28 of Set 9 | ukiah
# Processing Record 29 of Set 9 | tenenkou
# Processing Record 30 of Set 9 | comodoro rivadavia
# Processing Record 31 of Set 9 | achiotal
# City not found. Skipping...
# Processing Record 32 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 9 | hamada
# Processing Record 34 of Set 9 | daokou
# Processing Record 35 of Set 9 | konosha
# Processing Record 36 of Set 9 | maloy
# Processing Record 37 of Set 9 | doka
# Processing Record 38 of Set 9 | revyakino
# Processing Record 39 of Set 9 | ola
# Processing Record 40 of Set 9 | jiwani
# Processing Record 41 of Set 9 | zhanaozen
# Processing Record 42 of Set 9 | moroto
# Processing Record 43 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 9 | breznik
# Processing Record 45 of Set 9 | koppal
# Processing Record 46 of Set 9 | ankeny
# Processing Record 47 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 49 of Set 9 | hamilton
# Processing Record 50 of Set 9 | bellinge
# Processing Record 1 of Set 10 | simao
# Processing Record 2 of Set 10 | bonavista
# Processing Record 3 of Set 10 | chicama
# Processing Record 4 of Set 10 | pangody
# Processing Record 5 of Set 10 | gao
# Processing Record 6 of Set 10 | lavrentiya
# Processing Record 7 of Set 10 | nago
# Processing Record 8 of Set 10 | necochea
# Processing Record 9 of Set 10 | karratha
# Processing Record 10 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 10 | tyrma
# Processing Record 12 of Set 10 | namatanai
# Processing Record 13 of Set 10 | talara
# Processing Record 14 of Set 10 | curitibanos
# Processing Record 15 of Set 10 | saint george
# Processing Record 16 of Set 10 | congonhas
# Processing Record 17 of Set 10 | ecoporanga
# Processing Record 18 of Set 10 | kathu
# Processing Record 19 of Set 10 | portales
# Processing Record 20 of Set 10 | bijar
# Processing Record 21 of Set 10 | mantua
# Processing Record 22 of Set 10 | ancud
# Processing Record 23 of Set 10 | waingapu
# Processing Record 24 of Set 10 | merta
# Processing Record 25 of Set 10 | cruzeiro do oeste
# Processing Record 26 of Set 10 | bereda
# Processing Record 27 of Set 10 | starogard gdanski
# Processing Record 28 of Set 10 | lobez
# Processing Record 29 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 10 | sohag
# Processing Record 31 of Set 10 | marsh harbour
# Processing Record 32 of Set 10 | avera
# Processing Record 33 of Set 10 | taksimo
# Processing Record 34 of Set 10 | kaa-khem
# Processing Record 35 of Set 10 | tallahassee
# Processing Record 36 of Set 10 | tandil
# Processing Record 37 of Set 10 | belaya gora
# Processing Record 38 of Set 10 | maralal
# Processing Record 39 of Set 10 | erzin
# Processing Record 40 of Set 10 | sambava
# Processing Record 41 of Set 10 | pasni
# Processing Record 42 of Set 10 | ambulu
# Processing Record 43 of Set 10 | almaznyy
# Processing Record 44 of Set 10 | bose
# Processing Record 45 of Set 10 | karasjok
# Processing Record 46 of Set 10 | oga
# Processing Record 47 of Set 10 | san ignacio
# Processing Record 48 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 10 | koungou
# Processing Record 50 of Set 10 | meadow lake
# Processing Record 1 of Set 11 | loyga
# Processing Record 2 of Set 11 | palauig
# Processing Record 3 of Set 11 | paraiso
# Processing Record 4 of Set 11 | puntarenas
# Processing Record 5 of Set 11 | bahia honda
# Processing Record 6 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 7 of Set 11 | mocorito
# Processing Record 8 of Set 11 | cabo san lucas
# Processing Record 9 of Set 11 | eirunepe
# Processing Record 10 of Set 11 | esperance
# Processing Record 11 of Set 11 | alagir
# Processing Record 12 of Set 11 | cortez
# Processing Record 13 of Set 11 | bosaso
# Processing Record 14 of Set 11 | richards bay
# Processing Record 15 of Set 11 | negru voda
# Processing Record 16 of Set 11 | tezu
# Processing Record 17 of Set 11 | huayapam
# City not found. Skipping...
# Processing Record 18 of Set 11 | nokaneng
# Processing Record 19 of Set 11 | umm lajj
# Processing Record 20 of Set 11 | catuday
# Processing Record 21 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 11 | tommot
# Processing Record 24 of Set 11 | narsaq
# Processing Record 25 of Set 11 | hovd
# Processing Record 26 of Set 11 | portobelo
# Processing Record 27 of Set 11 | bud
# Processing Record 28 of Set 11 | requena
# Processing Record 29 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 11 | kudahuvadhoo
# Processing Record 31 of Set 11 | te anau
# Processing Record 32 of Set 11 | moerai
# Processing Record 33 of Set 11 | casablanca
# Processing Record 34 of Set 11 | varhaug
# Processing Record 35 of Set 11 | chincholi
# Processing Record 36 of Set 11 | alofi
# Processing Record 37 of Set 11 | shaowu
# Processing Record 38 of Set 11 | mackay
# Processing Record 39 of Set 11 | fuerte olimpo
# Processing Record 40 of Set 11 | pak phanang
# Processing Record 41 of Set 11 | san patricio
# Processing Record 42 of Set 11 | aljezur
# Processing Record 43 of Set 11 | vao
# Processing Record 44 of Set 11 | sur
# Processing Record 45 of Set 11 | vredendal
# Processing Record 46 of Set 11 | kaili
# Processing Record 47 of Set 11 | visnes
# Processing Record 48 of Set 11 | yatou
# Processing Record 49 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 11 | sarwar
# Processing Record 1 of Set 12 | jiayuguan
# Processing Record 2 of Set 12 | xam nua
# Processing Record 3 of Set 12 | sorong
# Processing Record 4 of Set 12 | camana
# Processing Record 5 of Set 12 | nome
# Processing Record 6 of Set 12 | high level
# Processing Record 7 of Set 12 | saint-francois
# Processing Record 8 of Set 12 | zhadovka
# Processing Record 9 of Set 12 | great falls
# Processing Record 10 of Set 12 | barreirinhas
# Processing Record 11 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 12 of Set 12 | zhicheng
# Processing Record 13 of Set 12 | sangar
# Processing Record 14 of Set 12 | xichang
# Processing Record 15 of Set 12 | turukhansk
# Processing Record 16 of Set 12 | mtwara
# Processing Record 17 of Set 12 | katsuura
# Processing Record 18 of Set 12 | sopelana
# Processing Record 19 of Set 12 | honningsvag
# Processing Record 20 of Set 12 | koumac
# Processing Record 21 of Set 12 | marsa matruh
# Processing Record 22 of Set 12 | chino valley
# Processing Record 23 of Set 12 | tautira
# Processing Record 24 of Set 12 | kirakira
# Processing Record 25 of Set 12 | kapoeta
# Processing Record 26 of Set 12 | dalinghe
# City not found. Skipping...
# Processing Record 27 of Set 12 | ust-maya
# Processing Record 28 of Set 12 | usinsk
# Processing Record 29 of Set 12 | alta floresta
# Processing Record 30 of Set 12 | basqal
# Processing Record 31 of Set 12 | silver city
# Processing Record 32 of Set 12 | mae ramat
# Processing Record 33 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 12 | shenjiamen
# Processing Record 35 of Set 12 | gueret
# Processing Record 36 of Set 12 | srandakan
# Processing Record 37 of Set 12 | anderson
# Processing Record 38 of Set 12 | lewiston
# Processing Record 39 of Set 12 | kruisfontein
# Processing Record 40 of Set 12 | clinton
# Processing Record 41 of Set 12 | zafra
# Processing Record 42 of Set 12 | baherden
# Processing Record 43 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 12 | komsomolskiy
# Processing Record 45 of Set 12 | lagunas
# Processing Record 46 of Set 12 | krasnoselkup
# Processing Record 47 of Set 12 | russell
# Processing Record 48 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 12 | mogok
# Processing Record 50 of Set 12 | saint-michel-des-saints
# Processing Record 1 of Set 13 | wewak
# Processing Record 2 of Set 13 | vestmanna
# Processing Record 3 of Set 13 | aripuana
# Processing Record 4 of Set 13 | luderitz
# Processing Record 5 of Set 13 | bastrop
# Processing Record 6 of Set 13 | praia
# Processing Record 7 of Set 13 | corinto
# Processing Record 8 of Set 13 | sao jose da coroa grande
# Processing Record 9 of Set 13 | lata
# Processing Record 10 of Set 13 | portland
# Processing Record 11 of Set 13 | bom jesus
# Processing Record 12 of Set 13 | viransehir
# Processing Record 13 of Set 13 | acapulco
# Processing Record 14 of Set 13 | saint-joseph
# Processing Record 15 of Set 13 | viedma
# Processing Record 16 of Set 13 | sioux lookout
# Processing Record 17 of Set 13 | pangoa
# Processing Record 18 of Set 13 | kilindoni
# Processing Record 19 of Set 13 | amazar
# Processing Record 20 of Set 13 | olinda
# Processing Record 21 of Set 13 | saint anthony
# Processing Record 22 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 23 of Set 13 | lanivtsi
# Processing Record 24 of Set 13 | martapura
# Processing Record 25 of Set 13 | khash
# Processing Record 26 of Set 13 | vikhorevka
# Processing Record 27 of Set 13 | muros
# Processing Record 28 of Set 13 | hathras
# Processing Record 29 of Set 13 | arman
# Processing Record 30 of Set 13 | buin
# Processing Record 31 of Set 13 | poronaysk
# Processing Record 32 of Set 13 | pocone
# Processing Record 33 of Set 13 | ban nahin
# Processing Record 34 of Set 13 | fukue
# Processing Record 35 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 13 | kontagora
# Processing Record 37 of Set 13 | nuuk
# Processing Record 38 of Set 13 | odweyne
# Processing Record 39 of Set 13 | carutapera
# Processing Record 40 of Set 13 | kodinsk
# Processing Record 41 of Set 13 | takestan
# Processing Record 42 of Set 13 | seoul
# Processing Record 43 of Set 13 | keti bandar
# Processing Record 44 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 13 | leshukonskoye
# Processing Record 46 of Set 13 | veinticinco de mayo
# Processing Record 47 of Set 13 | ouro preto do oeste
# Processing Record 48 of Set 13 | muyuka
# Processing Record 49 of Set 13 | port blair
# Processing Record 50 of Set 13 | kosh-agach
# Processing Record 1 of Set 14 | salisbury
# Processing Record 2 of Set 14 | asenovgrad
# Processing Record 3 of Set 14 | rosetta
# Processing Record 4 of Set 14 | angoche
# Processing Record 5 of Set 14 | igrim
# Processing Record 6 of Set 14 | harbour breton
# Processing Record 7 of Set 14 | gandajika
# Processing Record 8 of Set 14 | oranjemund
# Processing Record 9 of Set 14 | forssa
# Processing Record 10 of Set 14 | okha
# Processing Record 11 of Set 14 | yerkoy
# Processing Record 12 of Set 14 | manta
# Processing Record 13 of Set 14 | jinchang
# Processing Record 14 of Set 14 | bilma
# Processing Record 15 of Set 14 | soyo
# Processing Record 16 of Set 14 | jasidih
# Processing Record 17 of Set 14 | charters towers
# Processing Record 18 of Set 14 | margherita
# Processing Record 19 of Set 14 | bubaque
# Processing Record 20 of Set 14 | kaihua
# Processing Record 21 of Set 14 | severo-yeniseyskiy
# Processing Record 22 of Set 14 | lebanon
# Processing Record 23 of Set 14 | villa carlos paz
# Processing Record 24 of Set 14 | kusu
# Processing Record 25 of Set 14 | green river
# Processing Record 26 of Set 14 | nyurba
# Processing Record 27 of Set 14 | trelew
# Processing Record 28 of Set 14 | am timan
# Processing Record 29 of Set 14 | aborlan
# Processing Record 30 of Set 14 | havlickuv brod
# Processing Record 31 of Set 14 | brindisi
# Processing Record 32 of Set 14 | kaseda
# Processing Record 33 of Set 14 | perisani
# Processing Record 34 of Set 14 | ahuimanu
# Processing Record 35 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 36 of Set 14 | tevaitoa
# Processing Record 37 of Set 14 | livingston
# Processing Record 38 of Set 14 | berbera
# Processing Record 39 of Set 14 | grand gaube
# Processing Record 40 of Set 14 | tolaga bay
# Processing Record 41 of Set 14 | jaynagar-majilpur
# Processing Record 42 of Set 14 | nchelenge
# Processing Record 43 of Set 14 | tucurui
# Processing Record 44 of Set 14 | inirida
# Processing Record 45 of Set 14 | magadan
# Processing Record 46 of Set 14 | tavricheskoye
# Processing Record 47 of Set 14 | eagle pass
# Processing Record 48 of Set 14 | xuchang
# Processing Record 49 of Set 14 | karsun
# Processing Record 50 of Set 14 | havre-saint-pierre
# Processing Record 1 of Set 15 | milton
# Processing Record 2 of Set 15 | nautla
# Processing Record 3 of Set 15 | auki
# Processing Record 4 of Set 15 | el centro
# Processing Record 5 of Set 15 | chernyshevskiy
# Processing Record 6 of Set 15 | olden
# Processing Record 7 of Set 15 | dolinsk
# Processing Record 8 of Set 15 | mutsu
# Processing Record 9 of Set 15 | lazaro cardenas
# Processing Record 10 of Set 15 | adrar
# Processing Record 11 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 15 | derzhavinsk
# Processing Record 13 of Set 15 | khuzhir
# Processing Record 14 of Set 15 | medak
# Processing Record 15 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 15 | sayyan
# Processing Record 17 of Set 15 | primorsk
# Processing Record 18 of Set 15 | mersing
# Processing Record 19 of Set 15 | santa maria
# Processing Record 20 of Set 15 | kawalu
# Processing Record 21 of Set 15 | sakaiminato
# Processing Record 22 of Set 15 | brazzaville
# Processing Record 23 of Set 15 | henderson
# Processing Record 24 of Set 15 | yanam
# Processing Record 25 of Set 15 | chagoda
# Processing Record 26 of Set 15 | vengerovo
# Processing Record 27 of Set 15 | flin flon
# Processing Record 28 of Set 15 | bambanglipuro
# Processing Record 29 of Set 15 | doctor arroyo
# Processing Record 30 of Set 15 | zhaotong
# Processing Record 31 of Set 15 | lavumisa
# Processing Record 32 of Set 15 | rio tercero
# Processing Record 33 of Set 15 | aranos
# Processing Record 34 of Set 15 | ambilobe
# Processing Record 35 of Set 15 | ibra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 674

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Mareeba -17.00  145.43     89.01        27          43        5.01
# 1     Bilibino  68.05  166.44     52.90        52          83       10.22
# 2       Bethel  41.37  -73.41     62.01        87           1        3.91
# 3  Pangnirtung  66.15  -65.71     58.77        53         100        6.71
# 4       Hobart -42.88  147.33     57.20        50          75       12.75
# 5      Mataura -46.19  168.86     55.00        83          82        8.99
# 6      Qaanaaq  77.48  -69.36     43.56        77         100        4.65
# 7   Mahibadhoo   3.78   72.97     82.58        67          64        6.20
# 8    Hithadhoo  -0.60   73.08     84.43        71          36        8.70
# 9  Tuktoyaktuk  69.45 -133.04     59.00        72          20        2.24
#
#   Current Description Country                 Date
# 0    scattered clouds      AU  2020-08-19 04:27:44
# 1       broken clouds      RU  2020-08-19 04:27:44
# 2           clear sky      US  2020-08-19 04:27:44
# 3     overcast clouds      CA  2020-08-19 04:27:44
# 4       broken clouds      AU  2020-08-19 04:26:11
# 5       broken clouds      NZ  2020-08-19 04:27:45
# 6     overcast clouds      GL  2020-08-19 04:27:45
# 7       broken clouds      MV  2020-08-19 04:27:45
# 8    scattered clouds      MV  2020-08-19 04:27:46
# 9          few clouds      CA  2020-08-19 04:27:46

# %%
# Organize the  columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mareeba      AU -17.00  145.43     89.01        27          43
# 1     Bilibino      RU  68.05  166.44     52.90        52          83
# 2       Bethel      US  41.37  -73.41     62.01        87           1
# 3  Pangnirtung      CA  66.15  -65.71     58.77        53         100
# 4       Hobart      AU -42.88  147.33     57.20        50          75
# 5      Mataura      NZ -46.19  168.86     55.00        83          82
# 6      Qaanaaq      GL  77.48  -69.36     43.56        77         100
# 7   Mahibadhoo      MV   3.78   72.97     82.58        67          64
# 8    Hithadhoo      MV  -0.60   73.08     84.43        71          36
# 9  Tuktoyaktuk      CA  69.45 -133.04     59.00        72          20
#
#    Wind Speed Current Description
# 0        5.01    scattered clouds
# 1       10.22       broken clouds
# 2        3.91           clear sky
# 3        6.71     overcast clouds
# 4       12.75       broken clouds
# 5        8.99       broken clouds
# 6        4.65     overcast clouds
# 7        6.20       broken clouds
# 8        8.70    scattered clouds
# 9        2.24          few clouds

# %%
# Create and export the final Data Frame into a CSV
city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
